# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import warnings

# %%
import detect_simpsons_paradox as dsp

# %%
import os
cwd = os.getcwd()

# %%
iris_df = pd.read_csv('iris.csv')

# %%
result = dsp.detect_simpsons_paradox(iris_df)
print(result)
# Out:
#     allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0 -0.109369      0      1     0.746780       class      Iris-setosa
# 1 -0.420516      1      2     0.176695       class      Iris-setosa
# 2 -0.356544      1      3     0.279973       class      Iris-setosa
# 3 -0.109369      0      1     0.525911       class  Iris-versicolor
# 4 -0.420516      1      2     0.560522       class  Iris-versicolor
# 5 -0.356544      1      3     0.663999       class  Iris-versicolor
# 6 -0.109369      0      1     0.457228       class   Iris-virginica
# 7 -0.420516      1      2     0.401045       class   Iris-virginica
# 8 -0.356544      1      3     0.537728       class   Iris-virginica

# %%
fig = plt.figure()
font = {'weight':'normal'}
plt.rc('font', **font)
colors = {'Iris-setosa':'red', 'Iris-versicolor':'blue', 'Iris-virginica':'green'}
markers = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'s'}

#plt.scatter(iris_df['sepal length'], iris_df['sepal width'], c=iris_df['class'].apply(lambda x: colors[x]))
for i in range(len(iris_df['sepal length'])):
    plt.scatter(iris_df['sepal length'][i], iris_df['sepal width'][i],c=colors[iris_df['class'][i]], marker=markers[iris_df['class'][i]], label=iris_df['class'][i])


plt.xlabel('sepal length',  fontsize=24)
plt.ylabel('sepal width', fontsize=24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', marker='x', label='Iris-setosa')
#green_patch = mpatches.Patch(color='blue', marker='o', label='Iris-versicolor')
#blue_patch = mpatches.Patch(color='green', marker='s', label='Iris-virginica')
#plt.legend(handles=[red_patch, green_patch, blue_patch])
from collections import OrderedDict
handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), prop={'size':15})

# Add correlation line
axes = plt.gca()
x = iris_df['sepal length']
y = iris_df['sepal width']

m, b = np.polyfit(x, y, 1)
X_plot = np.linspace(axes.get_xlim()[0],axes.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '--',color='black')

setosa = iris_df[iris_df['class'] =='Iris-setosa']
versicolor = iris_df[iris_df['class'] =='Iris-versicolor']
virginica = iris_df[iris_df['class'] =='Iris-virginica']
x1 = setosa['sepal length']
y1 = setosa['sepal width']

m1, b1 = np.polyfit(x1, y1, 1)
#print(axes.get_xlim()[0])
#print(axes.get_xlim()[1])
X_plot1 = np.linspace(axes.get_xlim()[0],axes.get_xlim()[1]-2,100)
plt.plot(X_plot1, m1*X_plot1 + b1, '-', color='red')

x2 = versicolor['sepal length']
y2 = versicolor['sepal width']

m, b = np.polyfit(x2, y2, 1)
X_plot = np.linspace(axes.get_xlim()[0]+0.5,axes.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '-', color='blue')

x3 = virginica['sepal length']
y3 = virginica['sepal width']

m, b = np.polyfit(x3, y3, 1)
X_plot = np.linspace(axes.get_xlim()[0]+0.5,axes.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '-', color='green')

plt.show()

#fig.savefig('iris1.jpg')

# %%
fig = plt.figure()
colors = {'Iris-setosa':'red', 'Iris-versicolor':'blue', 'Iris-virginica':'green'}
markers = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'s'}

#plt.scatter(iris_df['sepal width'], iris_df['petal length'], c=iris_df['class'].apply(lambda x: colors[x]))

for i in range(len(iris_df['sepal width'])):
    plt.scatter(iris_df['sepal width'][i], iris_df['petal length'][i],c=colors[iris_df['class'][i]], marker=markers[iris_df['class'][i]], label=iris_df['class'][i])



plt.xlabel('sepal width',  fontsize=24)
plt.ylabel('petal length', fontsize=24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='Iris-setosa')
#green_patch = mpatches.Patch(color='blue', label='Iris-versicolor')
#blue_patch = mpatches.Patch(color='green', label='Iris-virginica')
#plt.legend(handles=[red_patch, green_patch, blue_patch])

from collections import OrderedDict
handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), prop={'size':15})

# Add correlation line
axes = plt.gca()
x = iris_df['sepal width']
y = iris_df['petal length']

m, b = np.polyfit(x, y, 1)
X_plot = np.linspace(axes.get_xlim()[0],axes.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '--',color='black')

setosa = iris_df[iris_df['class'] =='Iris-setosa']
versicolor = iris_df[iris_df['class'] =='Iris-versicolor']
virginica = iris_df[iris_df['class'] =='Iris-virginica']
x1 = setosa['sepal width']
y1 = setosa['petal length']

m1, b1 = np.polyfit(x1, y1, 1)
print(axes.get_xlim()[0])
print(axes.get_xlim()[1])
X_plot1 = np.linspace(2,4.5,100)
plt.plot(X_plot1, m1*X_plot1 + b1, '-', color='red')

x2 = versicolor['sepal width']
y2 = versicolor['petal length']

m, b = np.polyfit(x2, y2, 1)

X_plot = np.linspace(1.9,3.5,100)
plt.plot(X_plot, m*X_plot + b, '-', color='blue')

x3 = virginica['sepal width']
y3 = virginica['petal length']

m, b = np.polyfit(x3, y3, 1)
X_plot = np.linspace(2,4,100)
plt.plot(X_plot, m*X_plot + b, '-', color='green')

plt.show()

#fig.savefig('iris2.jpg')
# Out:
# 1.72670936354
# 4.66456783278

# %%
fig = plt.figure()
colors = {'Iris-setosa':'red', 'Iris-versicolor':'blue', 'Iris-virginica':'green'}
markers = {'Iris-setosa':'x', 'Iris-versicolor':'o', 'Iris-virginica':'s'}


#plt.scatter(iris_df['sepal width'], iris_df['petal width'], c=iris_df['class'].apply(lambda x: colors[x]))
for i in range(len(iris_df['sepal width'])):
    test = plt.scatter(iris_df['sepal width'][i], iris_df['petal width'][i],c=colors[iris_df['class'][i]], marker=markers[iris_df['class'][i]], label=iris_df['class'][i])


plt.xlabel('sepal width',  fontsize=24)
plt.ylabel('petal width', fontsize=24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
#import matplotlib.patches as mpatches
#red_patch = mpatches.Patch(color='red', label='Iris-setosa')
#green_patch = mpatches.Patch(color='blue', label='Iris-versicolor')
#blue_patch = mpatches.Patch(color='green', label='Iris-virginica')
#plt.legend(handles=[red_patch, green_patch, blue_patch])
from collections import OrderedDict
handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), prop={'size':15})

# Add correlation line
axes = plt.gca()
x = iris_df['sepal width']
y = iris_df['petal width']

m, b = np.polyfit(x, y, 1)
X_plot = np.linspace(axes.get_xlim()[0],axes.get_xlim()[1],100)
plt.plot(X_plot, m*X_plot + b, '--',color='black')

setosa = iris_df[iris_df['class'] =='Iris-setosa']
versicolor = iris_df[iris_df['class'] =='Iris-versicolor']
virginica = iris_df[iris_df['class'] =='Iris-virginica']
x1 = setosa['sepal width']
y1 = setosa['petal width']

m1, b1 = np.polyfit(x1, y1, 1)
print(axes.get_xlim()[0])
print(axes.get_xlim()[1])
X_plot1 = np.linspace(2,4.5,100)
plt.plot(X_plot1, m1*X_plot1 + b1, '-', color='red')

x2 = versicolor['sepal width']
y2 = versicolor['petal width']

m, b = np.polyfit(x2, y2, 1)

X_plot = np.linspace(1.9,3.5,100)
plt.plot(X_plot, m*X_plot + b, '-', color='blue')

x3 = virginica['sepal width']
y3 = virginica['petal width']

m, b = np.polyfit(x3, y3, 1)
X_plot = np.linspace(2,4,100)
plt.plot(X_plot, m*X_plot + b, '-', color='green')

plt.show()
#fig.savefig('iris3.jpg')
#fig.savefig('iris3.eps', format='eps', dpi=1000)
# Out:
# 1.72670936354
# 4.66456783278

# %%
import random
# sample 0.1
rows1 = random.sample(list(iris_df.index), int(len(iris_df)*0.1))
iris_df1 = iris_df.loc[rows1]
dsp.detect_simpsons_paradox(iris_df1)
# Out:
#      allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0  -0.227319      0      1     0.953821       class      Iris-setosa
# 1   0.809221      0      2    -0.188982       class      Iris-setosa
# 2   0.676404      0      3    -0.188982       class      Iris-setosa
# 3  -0.377243      1      2     0.114708       class      Iris-setosa
# 4  -0.243601      1      3     0.114708       class      Iris-setosa
# 5  -0.227319      0      1     0.381013       class  Iris-versicolor
# 6  -0.377243      1      2     0.772380       class  Iris-versicolor
# 7  -0.243601      1      3     0.680367       class  Iris-versicolor
# 8   0.676404      0      3    -0.129674       class   Iris-virginica
# 9  -0.377243      1      2     0.247117       class   Iris-virginica
# 10 -0.243601      1      3     0.900960       class   Iris-virginica

# %%
import random
# sample 0.3
rows3 = random.sample(list(iris_df.index), int(len(iris_df)*0.3))
iris_df3 = iris_df.loc[rows3]
dsp.detect_simpsons_paradox(iris_df3)
# Out:
#     allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0 -0.124426      0      1     0.837288       class      Iris-setosa
# 1 -0.419493      1      2     0.028596       class      Iris-setosa
# 2 -0.329962      1      3     0.419342       class      Iris-setosa
# 3 -0.124426      0      1     0.479807       class  Iris-versicolor
# 4 -0.419493      1      2     0.421415       class  Iris-versicolor
# 5 -0.329962      1      3     0.574473       class  Iris-versicolor
# 6 -0.124426      0      1     0.116444       class   Iris-virginica
# 7 -0.419493      1      2     0.068440       class   Iris-virginica
# 8 -0.329962      1      3     0.505031       class   Iris-virginica

# %%
import random
# sample 0.5
rows5 = random.sample(list(iris_df.index), int(len(iris_df)*0.5))
iris_df5 = iris_df.loc[rows5]
dsp.detect_simpsons_paradox(iris_df5)
# Out:
#     allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0 -0.034628      0      1     0.695021       class      Iris-setosa
# 1 -0.307641      1      2     0.088429       class      Iris-setosa
# 2 -0.034628      0      1     0.361908       class  Iris-versicolor
# 3 -0.307641      1      2     0.443441       class  Iris-versicolor
# 4 -0.281760      1      3     0.572714       class  Iris-versicolor
# 5 -0.034628      0      1     0.599916       class   Iris-virginica
# 6 -0.307641      1      2     0.514922       class   Iris-virginica
# 7 -0.281760      1      3     0.439826       class   Iris-virginica

# %%
import random
# sample 0.6
rows6 = random.sample(list(iris_df.index), int(len(iris_df)*0.6))
iris_df6 = iris_df.loc[rows6]
dsp.detect_simpsons_paradox(iris_df6)
# Out:
#     allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0 -0.069554      0      1     0.752300       class      Iris-setosa
# 1 -0.375319      1      2     0.128528       class      Iris-setosa
# 2 -0.302330      1      3     0.241978       class      Iris-setosa
# 3 -0.069554      0      1     0.453122       class  Iris-versicolor
# 4 -0.375319      1      2     0.498258       class  Iris-versicolor
# 5 -0.302330      1      3     0.689843       class  Iris-versicolor
# 6 -0.069554      0      1     0.602276       class   Iris-virginica
# 7 -0.375319      1      2     0.595568       class   Iris-virginica
# 8 -0.302330      1      3     0.561599       class   Iris-virginica

# %%
import random
# sample 0.9
rows9 = random.sample(list(iris_df.index), int(len(iris_df)*0.9))
iris_df9 = iris_df.loc[rows9]
dsp.detect_simpsons_paradox(iris_df9)
# Out:
#     allCorr  attr1  attr2  reverseCorr groupbyAttr         subgroup
# 0 -0.126843      0      1     0.740275       class      Iris-setosa
# 1 -0.458584      1      2     0.125933       class      Iris-setosa
# 2 -0.392645      1      3     0.378172       class      Iris-setosa
# 3 -0.126843      0      1     0.627155       class  Iris-versicolor
# 4 -0.458584      1      2     0.673308       class  Iris-versicolor
# 5 -0.392645      1      3     0.785060       class  Iris-versicolor
# 6 -0.126843      0      1     0.460214       class   Iris-virginica
# 7 -0.458584      1      2     0.412546       class   Iris-virginica
# 8 -0.392645      1      3     0.536424       class   Iris-virginica
