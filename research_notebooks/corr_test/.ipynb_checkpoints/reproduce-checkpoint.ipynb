# %%
import wiggum as wg
import pandas as pd
import numpy as np
import timeit
import seaborn as sns
import warnings
from itertools import chain
warnings.filterwarnings('ignore')

# %%
final=pd.DataFrame()
# runs tests for two code sources returns list of results
def test_scalability(labeled_df):

    times=[]
    for command in commands:
        for pearson_obj in objs:

            statement=command.format(pearson_obj)
            print(statement)
            t=timeit.repeat(statement, prereqs, repeat=10, number=100)
            times.append(t)
            print(t)
    timed = [ele for lis in times for ele in lis]
    return timed

# creates dataframe from all varaiables used for testing
def create_df(N, number_cluster, num_splitby, labeled_df, num_dep=None, num_indep=None, num_dep_indep=None):
    timings=test_scalability(labeled_df)
    function_names=['cct', 'get_subgroup_trends', 'get_trends (agg)', 'get_trends (sub)']
    result_df=pd.DataFrame(columns=['times', 'data', 'function'])
    # setting function column
    function=[]
    for ele in function_names:
        function.extend([ele]*20)
    # setting version column
    version=[['v1']*10, ['v2']*10]*len(function_names)
    version=list(chain.from_iterable(version))
    # setting trial column
    trial=list(range(10))*(len(function_names)*2)

    data_name='synthetic {}'.format(N)
    
    result_df['times']=timings
    result_df['function']=function
    result_df['data']=str(data_name)
    result_df['trial']=trial
    result_df['version']=version
    result_df['number_cluster']=number_cluster
    result_df['num_splitby']=num_splitby
    if num_dep_indep==None:
        result_df['independent']=num_indep
        result_df['dependent']=num_dep
    else:
        result_df['dep_indep_vars']=num_dep_indep
        
    return result_df

# %%
import mlsim
from mlsim import sp_plot

# %%
np.random.seed(20210627)


r_clusters =     [-.8, .5, .4, .7, -.6, .5, .4,-.9]  # magnitude correlation coefficient of clusters
cluster_spread = [ .3,-.2, .1,-.4, .2, -.1, .2,.4] # pearson correlation of means
p_sp_clusters =  [  1,  0,  0,  0,  1,   0,  0,  1] # portion of clusters with SP  #1 if r neg 0 if rpos
cluster_size =   [2,  3]#
domain_range = [0, 20, 0, 20] # of all data

# %%
''' IMPORTANT: default for this function is symetric cases, must specify number of
    dependent and independent variables for tests to run asymetrically'''

def generate_data(N, number_cluster, num_splitby, num_dep=None, num_indep=None, num_dep_indep=None):   
    k = [number_cluster]*40
    n_view = len(k)
    p_clusters = [[1/k_i]*k_i for k_i in k]
    many_sp_df = mlsim.geometric_indep_views_gmm_sp(n_view,r_clusters,cluster_size,cluster_spread,p_sp_clusters,
                domain_range,k,N,p_clusters)
    # print(many_sp_df.shape)
    labeled_df = wg.LabeledDataFrame(many_sp_df)

    n_view = int(len(labeled_df.df.columns) / 3)

    roles={'x1':['ignore']}
    if num_dep_indep==None:
        i=0
        while i<(n_view*2):
            if i<indep:
                roles.update({'x'+str(i+1):['independent']})
            elif i>indep and i<(indep+dep):
                roles.update({'x'+str(i+1):['dependent']})
            else:
                roles.update({'x'+str(i+1):['ignore']})
            i+=1
    else:
        # set dependent and independent for some xi, ignore for the rest
        dep_indep_list = np.random.choice(n_view*2, num_dep_indep)
        #print(dep_indep_list)
        roles = {'x'+str(i+1):['ignore'] if i not in dep_indep_list else ['independent','dependent'] 
                    for i in range(n_view*2)}
    # vars without 'x' in them are splitbys
    splitby_var_list = [cn for cn in labeled_df.df.columns if not('x' in cn)]
    # set splitby for some variable, ignore for the rest
    splitby_list = np.random.choice(splitby_var_list, num_splitby)
    roles.update( {c:['splitby'] if c in splitby_list else ['ignore'] for c in splitby_var_list})    

    count_list = []

    var_types = {'x'+str(i+1):'continuous' for i in range(n_view*2)}
    var_types.update( {c:'categorical' for c in splitby_var_list})
    weighting = {}

    labeled_df.set_counts(count_list)
    labeled_df.set_roles(roles)
    labeled_df.set_var_types(var_types)
    labeled_df.meta_df
    
    return labeled_df

# %%
# IMPORTANT Only use these lists to run symmetric cases
n_list = [1000, 5000, 10000]
number_cluster_list=[2, 4, 8, 16, 32]
num_dep_indep_list = [4, 8, 16]
num_splitby_list = [4, 8, 16]

# %%
# code for symmetric cases
result=pd.DataFrame()
objs=['pearson', 'pearson_2']
prereqs='from __main__ import labeled_df, pearson, pearson_2, objs, commands'
commands=["{}.compute_correlation_table(labeled_df.df, 'agg_trend')",
          'labeled_df.get_subgroup_trends_1lev([{}])',
         "{}.get_trends(labeled_df.df, 'agg_trend')",
         "{}.get_trends(labeled_df.df, 'sub_trend')"]

for N in n_list:
    for number_cluster in number_cluster_list:
        for num_dep_indep in num_dep_indep_list:
            for num_splitby in num_splitby_list:
                labeled_df=generate_data(N, number_cluster, num_splitby, num_dep_indep=num_dep_indep)
                pearson = wg.All_Pearson()
                pearson.get_trend_vars(labeled_df)

                pearson_2 = wg.trends.All_Pearson_V2()
                pearson_2.get_trend_vars(labeled_df)
                result_df=create_df(N, number_cluster, num_splitby, labeled_df, num_dep_indep=num_dep_indep)
                result=pd.concat([result, result_df])
result.to_csv('data/sym_vars')
# Out:
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.06471859999987828, 0.06380879999983335, 0.06346000000007734, 0.06392669999991085, 0.06335570000010193, 0.06331040000009125, 0.06330960000013874, 0.0632949999999255, 0.0633565999999064, 0.06333479999989322]
# pearson_2.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.06346989999997277, 0.06335229999990588, 0.06343549999996867, 0.06373499999995147, 0.06345759999999245, 0.0632413999999244, 0.06325549999996838, 0.06352349999997386, 0.06345630000009805, 0.06305829999996604]
# labeled_df.get_subgroup_trends_1lev([pearson])
# [0.3864126999999371, 0.3486820999999054, 0.34858310000004167, 0.3485502000000906, 0.3517603999998755, 0.35589820000018335, 0.35604429999989406, 0.3554036000000451, 0.3549507000000176, 0.3555355999999392]
# labeled_df.get_subgroup_trends_1lev([pearson_2])
# [0.3469347000000198, 0.3469728000000032, 0.3471064000000297, 0.3474615000000085, 0.3473758000000089, 0.347298500000079, 0.347195499999998, 0.34804669999994076, 0.3472394999998869, 0.34685880000006364]
# pearson.get_trends(labeled_df.df, 'agg_trend')
# [0.15431850000004488, 0.15185489999998936, 0.1513099000001148, 0.15116820000002917, 0.15112810000005084, 0.15137469999990572, 0.15123730000004798, 0.151282700000138, 0.15141640000001644, 0.15162859999986722]
# pearson_2.get_trends(labeled_df.df, 'agg_trend')
# [0.1859646000000339, 0.18630110000003697, 0.18589199999996708, 0.1862676000000647, 0.18519019999985176, 0.18549989999996797, 0.18551589999992757, 0.18550520000007964, 0.18555899999978465, 0.18602469999996174]
# pearson.get_trends(labeled_df.df, 'sub_trend')
# [0.15263260000006085, 0.15206820000003063, 0.15119360000016968, 0.15136329999995723, 0.15146049999998468, 0.1514190000000326, 0.15165209999986473, 0.15156420000016624, 0.15156200000001263, 0.15162659999987227]
# pearson_2.get_trends(labeled_df.df, 'sub_trend')
# [0.18680829999993875, 0.1867050000000745, 0.18567120000011528, 0.18546870000000126, 0.1855387000000519, 0.18547159999980067, 0.18637089999992895, 0.1854427000000669, 0.18556050000006508, 0.18543770000019322]
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.07210450000002311, 0.07168000000001484, 0.07208930000001601, 0.0715319000000818, 0.07137829999987844, 0.07136700000000928, 0.07139759999995476, 0.07155219999981455, 0.0714868000000024, 0.07141410000008364]
# pearson_2.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.07250980000003437, 0.0714933999997811, 0.07284619999995812, 0.07162640000001375, 0.07163470000000416, 0.07158909999998286, 0.07146170000009988, 0.07144010000001799, 0.07145650000006754, 0.0715092000000368]
# labeled_df.get_subgroup_trends_1lev([pearson])
# [0.3991281999999501, 0.34927429999993365, 0.34878029999981663, 0.34948290000011184, 0.34911140000008345, 0.34934320000002117, 0.3495318000000225, 0.35042429999998603, 0.35128420000000915, 0.3516930000000684]
# labeled_df.get_subgroup_trends_1lev([pearson_2])
# [0.34918870000001334, 0.3488800000000083, 0.34929429999988315, 0.34839080000006106, 0.34834460000001854, 0.34849099999996724, 0.34888440000008814, 0.3478878999999324, 0.34839469999997164, 0.3476731999999174]
# pearson.get_trends(labeled_df.df, 'agg_trend')
# [0.1634871999999632, 0.16137739999999212, 0.16123620000007577, 0.16107959999999366, 0.1608829000001606, 0.16140390000009575, 0.1609976000002007, 0.16096010000001115, 0.1610992000000806, 0.16088909999984935]
# pearson_2.get_trends(labeled_df.df, 'agg_trend')
# [0.28263990000004924, 0.28048139999987143, 0.28041890000008607, 0.2803664000000481, 0.2803427000001193, 0.2801706000000195, 0.28059619999999086, 0.2804532999998628, 0.28058319999991, 0.28086229999985335]
# pearson.get_trends(labeled_df.df, 'sub_trend')
# [0.16157819999989442, 0.16167880000011792, 0.16034300000001167, 0.16027399999984482, 0.1603935000000547, 0.16048640000008163, 0.16042510000011134, 0.16044579999993402, 0.16031370000018796, 0.16030559999990146]
# pearson_2.get_trends(labeled_df.df, 'sub_trend')
# [0.28260160000013457, 0.28030790000002526, 0.280361399999947, 0.2802486000000499, 0.2805336999999781, 0.2803564999999253, 0.2803980999999567, 0.2803891000000931, 0.2802424000001338, 0.2805713999998716]
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.07240630000001147, 0.07176859999981389, 0.07229000000006636, 0.07176690000005692, 0.07177660000002106, 0.07173660000012205, 0.07173010000019531, 0.07156880000002275, 0.07186690000003182, 0.07200850000003811]
# pearson_2.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.07222260000003189, 0.07172099999979764, 0.07208689999993112, 0.07157229999984338, 0.07158079999999245, 0.07151409999983116, 0.07156589999999596, 0.07150860000001558, 0.07154929999978776, 0.07146699999998418]
# labeled_df.get_subgroup_trends_1lev([pearson])
# [0.4444857000000866, 0.34927029999994375, 0.3503304000000753, 0.35765970000011293, 0.356559500000003, 0.3568706999999449, 0.3569279999999253, 0.3569411000000855, 0.3566280000000006, 0.35757360000002336]
# labeled_df.get_subgroup_trends_1lev([pearson_2])
# [0.358152999999902, 0.35763260000021546, 0.35924210000007406, 0.3577911000002132, 0.3576664999998229, 0.35911570000007487, 0.3577910999999858, 0.35417499999994106, 0.34960240000009435, 0.3502137999998922]
# pearson.get_trends(labeled_df.df, 'agg_trend')
# [0.16362819999994827, 0.16289830000005168, 0.1607137999999395, 0.1599765999999363, 0.1613792000000558, 0.16104629999995268, 0.16092759999992268, 0.160985299999993, 0.1609137999998893, 0.1606837000001633]
# pearson_2.get_trends(labeled_df.df, 'agg_trend')
# [0.28268789999992805, 0.2802924999998595, 0.28018489999999474, 0.28034789999992427, 0.27924750000011045, 0.28060560000017176, 0.2801887999999053, 0.27995199999986653, 0.27995229999987714, 0.2800525000000107]
# pearson.get_trends(labeled_df.df, 'sub_trend')
# [0.16161779999993087, 0.161898199999996, 0.16074559999992744, 0.16064510000001064, 0.16080090000014025, 0.16070049999984803, 0.16165649999993548, 0.16081789999998364, 0.16065469999989546, 0.16078300000003765]
# pearson_2.get_trends(labeled_df.df, 'sub_trend')
# [0.2827150000000529, 0.2808188000001337, 0.28054389999988416, 0.28076209999994717, 0.2807678000001488, 0.28030089999992924, 0.28079630000002, 0.28063670000005914, 0.28042409999989104, 0.28047090000018216]
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.1189483000000564, 0.11827210000001287, 0.11817330000008042, 0.11802149999994072, 0.11755239999979494, 0.11784599999987222, 0.11771449999992001, 0.11787949999984448, 0.1175441000000319, 0.11783420000006117]
# pearson_2.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.11850580000009359, 0.1181303000000753, 0.11770529999989776, 0.11772239999982048, 0.11823259999982838, 0.11783579999996618, 0.11765299999979106, 0.1176378999998633, 0.11777280000001156, 0.11783100000002378]
# labeled_df.get_subgroup_trends_1lev([pearson])
# [0.44180679999999484, 0.35157619999995404, 0.3507050000000618, 0.3502849999999853, 0.35083319999989726, 0.3515032999998766, 0.35180460000015046, 0.3522073999999975, 0.3522585999999137, 0.3512706999999864]
# labeled_df.get_subgroup_trends_1lev([pearson_2])
# [0.35137620000000425, 0.3504564999998365, 0.3505700999999135, 0.35101559999998244, 0.3517971999999645, 0.35076759999992646, 0.35061049999990246, 0.35045960000002196, 0.35078470000007655, 0.35085929999991095]
# pearson.get_trends(labeled_df.df, 'agg_trend')
# [0.21869749999996202, 0.2164353000000574, 0.2153424000000541, 0.21525050000013835, 0.2152294999998503, 0.2152112000001125, 0.2153158999999505, 0.21539930000017193, 0.2152922000000217, 0.21525500000007014]
# pearson_2.get_trends(labeled_df.df, 'agg_trend')
# [0.9719003000000157, 0.96886510000013, 0.9682970999999725, 0.9691402000000835, 0.9689037999999073, 0.9687387000001308, 0.9718304999998963, 0.9690023999999084, 0.9685488000000078, 0.9725449000000026]
# pearson.get_trends(labeled_df.df, 'sub_trend')
# [0.2174008000001777, 0.21543640000004416, 0.2153660999999829, 0.21531099999992875, 0.2153994000000239, 0.21512550000011288, 0.21528139999986706, 0.21500929999979235, 0.21507849999989048, 0.21528459999990446]
# pearson_2.get_trends(labeled_df.df, 'sub_trend')
# [0.9751915000001645, 0.9724475000000439, 0.9750062999999045, 0.9697363999998743, 0.9719617000000653, 0.9768976999998813, 0.9732113000000027, 0.9747370000000046, 0.9729932999998709, 0.972312200000033]
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16356/1572806309.py in <module>
#      18                 pearson_2 = wg.trends.All_Pearson_V2()
#      19                 pearson_2.get_trend_vars(labeled_df)
# ---> 20                 result_df=create_df(N, number_cluster, num_splitby, labeled_df, num_dep_indep=num_dep_indep)
#      21                 result=pd.concat([result, result_df])
#      22 result.to_csv('data/sym_vars')
#
# ~\AppData\Local\Temp/ipykernel_16356/4039963366.py in create_df(N, number_cluster, num_splitby, labeled_df, num_dep, num_indep, num_dep_indep)
#      16
#      17 def create_df(N, number_cluster, num_splitby, labeled_df, num_dep=None, num_indep=None, num_dep_indep=None):
# ---> 18     timings=test_scalability(labeled_df)
#      19     function_names=['cct', 'get_subgroup_trends', 'get_trends (agg)', 'get_trends (sub)']
#      20     result_df=pd.DataFrame(columns=['times', 'data', 'function'])
#
# ~\AppData\Local\Temp/ipykernel_16356/4039963366.py in test_scalability(labeled_df)
#       9             statement=command.format(pearson_obj)
#      10             print(statement)
# ---> 11             t=timeit.repeat(statement, prereqs, repeat=10, number=100)
#      12             times.append(t)
#      13             print(t)
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in repeat(stmt, setup, timer, repeat, number, globals)
#     236            repeat=default_repeat, number=default_number, globals=None):
#     237     """Convenience function to create Timer object and call repeat method."""
# --> 238     return Timer(stmt, setup, timer, globals).repeat(repeat, number)
#     239
#     240 def main(args=None, *, _wrap_timer=None):
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# --> 177             timing = self.inner(it, self.timer)
#     178         finally:
#     179             if gcold:
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in inner(_it, _timer)
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\wiggum\trend_components\statistical.py in compute_correlation_table(self, data_df, trend_col_name)
#      86             trend_name = '_'.join([self.name , trend_col_name])
#      87             # compute correlations
# ---> 88             corr_mat = data_df[corr_var_list].corr(method=self.corrtype)
#      89             # store the correlation matrix for later use
#      90             self.trend_precompute[trend_name] = corr_mat
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods)
#    9375         cols = numeric_df.columns
#    9376         idx = cols.copy()
# -> 9377         mat = numeric_df.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    9378
#    9379         if method == "pearson":
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in to_numpy(self, dtype, copy, na_value)
#    1654         """
#    1655         self._consolidate_inplace()
# -> 1656         result = self._mgr.as_array(
#    1657             transpose=self._AXIS_REVERSED, dtype=dtype, copy=copy, na_value=na_value
#    1658         )
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, dtype, copy, na_value)
#    1469
#    1470         if copy:
# -> 1471             arr = arr.copy()
#    1472
#    1473         if na_value is not lib.no_default:
#
# KeyboardInterrupt:

# %%
# IMPORTANT: only use these lists for assymetric cases
n_list = [1000, 5000, 1000]
number_cluster_list=[2, 4, 8, 16, 32]
num_indep_list = [5, 10, 15, 20, 25]
num_dep_list = [5, 10, 15, 20, 25]
num_splitby_list = [4, 8, 16]

# %%
# code for assymetric cases
result=pd.DataFrame()
indep=2
objs=['pearson', 'pearson_2']
prereqs='from __main__ import labeled_df, pearson, pearson_2, objs, commands'
commands=["{}.compute_correlation_table(labeled_df.df, 'agg_trend')",
          'labeled_df.get_subgroup_trends_1lev([{}])',
         "{}.get_trends(labeled_df.df, 'agg_trend')",
         "{}.get_trends(labeled_df.df, 'sub_trend')"]

while indep<=20:
    dep=2
    while dep<=20: 
        labeled_df=generate_data(N, number_cluster, dep, indep, num_splitby)
        pearson = wg.All_Pearson()
        pearson.get_trend_vars(labeled_df)

        pearson_2 = wg.trends.All_Pearson_V2()
        pearson_2.get_trend_vars(labeled_df)
        
        result_df=create_df(N, number_cluster, num_splitby, labeled_df, num_dep=dep, num_indep=indep, num_dep_indep=None)
        result=pd.concat([result, result_df])
        print('independents: ', indep)
        print('dependents: ', dep)
        dep+=2
    indep+=2
result.to_csv('data/aysm_vars')
# Out:
# pearson.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.05943969999998444, 0.0590841000000637, 0.05901959999982864, 0.0595023000000765, 0.05836330000011003, 0.05872389999990446, 0.058383000000048924, 0.05845410000006268, 0.0584180999999262, 0.05838029999995342]
# pearson_2.compute_correlation_table(labeled_df.df, 'agg_trend')
# [0.059160600000041086, 0.05876979999993637, 0.05827640000006795, 0.059663800000180345, 0.058154699999931836, 0.05829940000012357, 0.05833419999999023, 0.05850979999991068, 0.05867929999999433, 0.058954999999969004]
# labeled_df.get_subgroup_trends_1lev([pearson])
# [0.37353940000002694, 0.3465710999998919, 0.3480696999999964, 0.3478265999999621, 0.34687479999979587, 0.3484235000000808, 0.34607789999995475, 0.3494631999999456, 0.34736500000008164, 0.3481125000000702]
# labeled_df.get_subgroup_trends_1lev([pearson_2])
# [0.3469390000000203, 0.34677449999981036, 0.3471139000000676, 0.3471125999999458, 0.3465531000001647, 0.34611699999982193, 0.3480001999998876, 0.34858810000014273, 0.3514439000000493, 0.34910820000004605]
# pearson.get_trends(labeled_df.df, 'agg_trend')
# [0.14996350000001257, 0.1478103000001738, 0.14689450000014403, 0.14713800000004085, 0.14696140000000923, 0.14689849999990656, 0.146837000000005, 0.1471192000001338, 0.14739779999990787, 0.14687039999989793]
# pearson_2.get_trends(labeled_df.df, 'agg_trend')
# [0.12685579999993024, 0.12419960000011088, 0.12362800000005336, 0.12356359999989763, 0.12410520000003089, 0.1222138000000541, 0.12171260000013717, 0.1219479000001229, 0.12174800000002506, 0.12158429999999498]
# pearson.get_trends(labeled_df.df, 'sub_trend')
# [0.14624959999991916, 0.14595170000006874, 0.14532450000001518, 0.1450488000000405, 0.14522220000003472, 0.14564420000010614, 0.1451136000000588, 0.14509109999994507, 0.14511179999999513, 0.14622209999993174]
# pearson_2.get_trends(labeled_df.df, 'sub_trend')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16356/1186402539.py in <module>
#      19         pearson_2.get_trend_vars(labeled_df)
#      20
# ---> 21         result_df=create_df(N, number_cluster, num_splitby, labeled_df, num_dep=dep, num_indep=indep, num_dep_indep=None)
#      22         result=pd.concat([result, result_df])
#      23         print('independents: ', indep)
#
# ~\AppData\Local\Temp/ipykernel_16356/4039963366.py in create_df(N, number_cluster, num_splitby, labeled_df, num_dep, num_indep, num_dep_indep)
#      16
#      17 def create_df(N, number_cluster, num_splitby, labeled_df, num_dep=None, num_indep=None, num_dep_indep=None):
# ---> 18     timings=test_scalability(labeled_df)
#      19     function_names=['cct', 'get_subgroup_trends', 'get_trends (agg)', 'get_trends (sub)']
#      20     result_df=pd.DataFrame(columns=['times', 'data', 'function'])
#
# ~\AppData\Local\Temp/ipykernel_16356/4039963366.py in test_scalability(labeled_df)
#       9             statement=command.format(pearson_obj)
#      10             print(statement)
# ---> 11             t=timeit.repeat(statement, prereqs, repeat=10, number=100)
#      12             times.append(t)
#      13             print(t)
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in repeat(stmt, setup, timer, repeat, number, globals)
#     236            repeat=default_repeat, number=default_number, globals=None):
#     237     """Convenience function to create Timer object and call repeat method."""
# --> 238     return Timer(stmt, setup, timer, globals).repeat(repeat, number)
#     239
#     240 def main(args=None, *, _wrap_timer=None):
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in repeat(self, repeat, number)
#     203         r = []
#     204         for i in range(repeat):
# --> 205             t = self.timeit(number)
#     206             r.append(t)
#     207         return r
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# --> 177             timing = self.inner(it, self.timer)
#     178         finally:
#     179             if gcold:
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\timeit.py in inner(_it, _timer)
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\wiggum\trend_components\statistical.py in get_trends(self, data_df, trend_col_name)
#     291
#     292         # get correlations
# --> 293         corr_data = self.compute_correlation_table_V2(data_df)
#     294
#     295         # expand to trend and strength
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\wiggum\trend_components\statistical.py in compute_correlation_table_V2(self, data_df)
#     136             else:
#     137                 # not symmtetric, not groupby
# --> 138                 corr_data = [(i,d, data_df[d].corr(data_df[i], method=self.corrtype),'')
#     139                              for i,d in self.regression_vars]
#     140         else:
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\wiggum\trend_components\statistical.py in <listcomp>(.0)
#     136             else:
#     137                 # not symmtetric, not groupby
# --> 138                 corr_data = [(i,d, data_df[d].corr(data_df[i], method=self.corrtype),'')
#     139                              for i,d in self.regression_vars]
#     140         else:
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2506
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
# -> 2508             return nanops.nancorr(
#    2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\nanops.py in nancorr(a, b, method, min_periods)
#    1515         min_periods = 1
#    1516
# -> 1517     valid = notna(a) & notna(b)
#    1518     if not valid.all():
#    1519         a = a[valid]
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\dtypes\missing.py in notna(obj)
#     353     Name: 1, dtype: bool
#     354     """
# --> 355     res = isna(obj)
#     356     if is_scalar(res):
#     357         return not res
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     136     Name: 1, dtype: bool
#     137     """
# --> 138     return _isna(obj)
#     139
#     140
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\dtypes\missing.py in _isna(obj, inf_as_na)
#     169         return False
#     170     elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 171         return _isna_array(obj, inf_as_na=inf_as_na)
#     172     elif isinstance(obj, (ABCSeries, ABCIndex)):
#     173         result = _isna_array(obj._values, inf_as_na=inf_as_na)
#
# c:\users\patrick\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\dtypes\missing.py in _isna_array(values, inf_as_na)
#     252             result = ~np.isfinite(values)
#     253         else:
# --> 254             result = np.isnan(values)
#     255
#     256     return result
#
# KeyboardInterrupt:
