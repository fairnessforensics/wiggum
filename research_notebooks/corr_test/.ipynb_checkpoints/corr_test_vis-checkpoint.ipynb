# %%
import wiggum as wg
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'data\final_data')

# %%
data=data.drop(labels=['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
data
# Out:
#           times             data          function  trial version   size  \
# 0      0.566995   synthetic 1000               cct      0      v1   1000
# 1      0.216509   synthetic 1000               cct      1      v1   1000
# 2      0.203193   synthetic 1000               cct      2      v1   1000
# 3      0.208757   synthetic 1000               cct      3      v1   1000
# 4      0.214807   synthetic 1000               cct      4      v1   1000
# ...         ...              ...               ...    ...     ...    ...
# 10795  1.335702  synthetic 10000  get_trends (sub)      5      v2  10000
# 10796  1.334635  synthetic 10000  get_trends (sub)      6      v2  10000
# 10797  1.324797  synthetic 10000  get_trends (sub)      7      v2  10000
# 10798  1.350365  synthetic 10000  get_trends (sub)      8      v2  10000
# 10799  1.319914  synthetic 10000  get_trends (sub)      9      v2  10000
#
#        dep_indep_vars  number_cluster  num_splitby
# 0                   4               2            4
# 1                   4               2            4
# 2                   4               2            4
# 3                   4               2            4
# 4                   4               2            4
# ...               ...             ...          ...
# 10795              16              32           16
# 10796              16              32           16
# 10797              16              32           16
# 10798              16              32           16
# 10799              16              32           16
#
# [10800 rows x 9 columns]

# %%
sns.lmplot(data=data, x='trial', y='times', col='size', row='function', hue='version', fit_reg=False)

# %% [markdown]
# Note: for whatever reason in get_subgroup_trends() for version 1 the first trial always has much higher timings ans they seem to increase with the number of clusters.

# %%
sns.lmplot(data=data, x='trial', y='times', col='number_cluster', row='function', hue='version', fit_reg=False)

# %%
data_mean=data.groupby(['function', 'version', 'data', 'dep_indep_vars', 'number_cluster', 'num_splitby']).mean()
data_mean=data_mean.reset_index()
data_mean=data_mean.drop(['trial', 'Unnamed: 0.1', 'Unnamed: 0'], axis=1)
data_mean
# Out:
#               function version            data  dep_indep_vars  \
# 0                  cct      v1  synthetic 1000               4
# 1                  cct      v1  synthetic 1000               4
# 2                  cct      v1  synthetic 1000               4
# 3                  cct      v1  synthetic 1000               4
# 4                  cct      v1  synthetic 1000               4
# ...                ...     ...             ...             ...
# 1075  get_trends (sub)      v2  synthetic 5000              16
# 1076  get_trends (sub)      v2  synthetic 5000              16
# 1077  get_trends (sub)      v2  synthetic 5000              16
# 1078  get_trends (sub)      v2  synthetic 5000              16
# 1079  get_trends (sub)      v2  synthetic 5000              16
#
#       number_cluster  num_splitby     times    size
# 0                  2            4  0.245455  1000.0
# 1                  2            8  0.212040  1000.0
# 2                  2           16  0.208489  1000.0
# 3                  4            4  0.856469  1000.0
# 4                  4            8  0.276433  1000.0
# ...              ...          ...       ...     ...
# 1075              16            8  1.371908  5000.0
# 1076              16           16  0.826175  5000.0
# 1077              32            4  0.850527  5000.0
# 1078              32            8  0.840965  5000.0
# 1079              32           16  0.820601  5000.0
#
# [1080 rows x 8 columns]

# %%
sns.relplot(data=data_mean, x='dep_indep_vars', y='times', kind='line', col='data', row='function', hue='version')

# %%
sns.relplot(data=data_mean, x='number_cluster', y='times', kind='line', col='data', row='function', hue='version')

# %%
sns.relplot(data=data_mean, x='num_splitby', y='times', kind='line', col='function', row='data', hue='version')

# %%
vars_data=pd.read_csv('data/vars_data')
vars_data=vars_data.drop(labels=['Unnamed: 0'], axis=1)

# %%
vars_data['dep:indep']=vars_data['dependent']+(vars_data['independent'])*-1

# %%
vars_data
# Out:
#           times            data          function  trial version  independent  \
# 0      0.190346  synthetic 1000               cct      0      v1            2
# 1      0.171242  synthetic 1000               cct      1      v1            2
# 2      0.177055  synthetic 1000               cct      2      v1            2
# 3      0.173933  synthetic 1000               cct      3      v1            2
# 4      0.165573  synthetic 1000               cct      4      v1            2
# ...         ...             ...               ...    ...     ...          ...
# 7995  12.362285  synthetic 1000  get_trends (sub)      5      v2           20
# 7996  13.186259  synthetic 1000  get_trends (sub)      6      v2           20
# 7997  13.927814  synthetic 1000  get_trends (sub)      7      v2           20
# 7998  12.258961  synthetic 1000  get_trends (sub)      8      v2           20
# 7999  12.294675  synthetic 1000  get_trends (sub)      9      v2           20
#
#       dependent  dep:indep
# 0             2          0
# 1             2          0
# 2             2          0
# 3             2          0
# 4             2          0
# ...         ...        ...
# 7995         20          0
# 7996         20          0
# 7997         20          0
# 7998         20          0
# 7999         20          0
#
# [8000 rows x 8 columns]

# %%
vars_mean=vars_data.groupby(['function', 'version', 'data', 'independent', 'dependent']).mean()
vars_mean=vars_mean.reset_index()
vars_mean
# Out:
#              function version            data  independent  dependent  \
# 0                 cct      v1  synthetic 1000            2          2
# 1                 cct      v1  synthetic 1000            2          4
# 2                 cct      v1  synthetic 1000            2          6
# 3                 cct      v1  synthetic 1000            2          8
# 4                 cct      v1  synthetic 1000            2         10
# ..                ...     ...             ...          ...        ...
# 795  get_trends (sub)      v2  synthetic 1000           20         12
# 796  get_trends (sub)      v2  synthetic 1000           20         14
# 797  get_trends (sub)      v2  synthetic 1000           20         16
# 798  get_trends (sub)      v2  synthetic 1000           20         18
# 799  get_trends (sub)      v2  synthetic 1000           20         20
#
#          times  trial  dep:indep
# 0     0.173737    4.5        0.0
# 1     0.209446    4.5        2.0
# 2     0.246999    4.5        4.0
# 3     0.314753    4.5        6.0
# 4     0.267802    4.5        8.0
# ..         ...    ...        ...
# 795   7.420464    4.5       -8.0
# 796   8.562204    4.5       -6.0
# 797  10.108845    4.5       -4.0
# 798  11.292182    4.5       -2.0
# 799  12.709982    4.5        0.0
#
# [800 rows x 8 columns]

# %% [markdown]
# The following graphs use different levels of dependent and independent data to see how source code compares withoptmised code. The dep:indep variable shows the difference between dependent and independent varaiables for any given trial. negetiv evalues mean there are more independent variables hwile positive means there are more dependent variables. a value of zero means there is an equal number of dependent and independent variables

# %%
sns.relplot(data=vars_mean, x='dep:indep', y='times', kind='line', col='function', hue='version')

# %%
data=pd.read_csv(r'data\all_data')

# %%
data_1000=data[data['data']=='synthetic 1000']

# %%
data_1000
# Out:
#            times            data          function  trial version  \
# 0       0.360980  synthetic 1000               cct      0      v1
# 1       0.265732  synthetic 1000               cct      1      v1
# 2       0.250074  synthetic 1000               cct      2      v1
# 3       0.242783  synthetic 1000               cct      3      v1
# 4       0.251419  synthetic 1000               cct      4      v1
# ...          ...             ...               ...    ...     ...
# 11995  19.355300  synthetic 1000  get_trends (sub)      5      v2
# 11996  19.142270  synthetic 1000  get_trends (sub)      6      v2
# 11997  19.892193  synthetic 1000  get_trends (sub)      7      v2
# 11998  19.339939  synthetic 1000  get_trends (sub)      8      v2
# 11999  21.359327  synthetic 1000  get_trends (sub)      9      v2
#
#        number_cluster  num_splitby  independent  dependent
# 0                   2            4            5          5
# 1                   2            4            5          5
# 2                   2            4            5          5
# 3                   2            4            5          5
# 4                   2            4            5          5
# ...               ...          ...          ...        ...
# 11995               4           16           25         25
# 11996               4           16           25         25
# 11997               4           16           25         25
# 11998               4           16           25         25
# 11999               4           16           25         25
#
# [12000 rows x 9 columns]

# %%
data_1000['dep:indep']=data_1000['independent']+(data['dependent']*-1)

# %%
data_1000=data_1000.groupby(['function', 'version', 'data', 'dependent', 'independent', 'number_cluster', 'num_splitby']).mean()
data_1000=data_1000.reset_index()

# %%
data_1000
# Out:
#               function version            data  dependent  independent  \
# 0                  cct      v1  synthetic 1000          5            5
# 1                  cct      v1  synthetic 1000          5            5
# 2                  cct      v1  synthetic 1000          5            5
# 3                  cct      v1  synthetic 1000          5            5
# 4                  cct      v1  synthetic 1000          5            5
# ...                ...     ...             ...        ...          ...
# 1195  get_trends (sub)      v2  synthetic 1000         25           25
# 1196  get_trends (sub)      v2  synthetic 1000         25           25
# 1197  get_trends (sub)      v2  synthetic 1000         25           25
# 1198  get_trends (sub)      v2  synthetic 1000         25           25
# 1199  get_trends (sub)      v2  synthetic 1000         25           25
#
#       number_cluster  num_splitby      times  trial  dep:indep
# 0                  2            4   0.272983    4.5        0.0
# 1                  2            8   0.341954    4.5        0.0
# 2                  2           16   0.238793    4.5        0.0
# 3                  4            4   0.234197    4.5        0.0
# 4                  4            8   0.241378    4.5        0.0
# ...              ...          ...        ...    ...        ...
# 1195               2            8  19.477171    4.5       20.0
# 1196               2           16  19.674387    4.5       20.0
# 1197               4            4  19.800731    4.5       20.0
# 1198               4            8  20.265992    4.5       20.0
# 1199               4           16  19.707922    4.5       20.0
#
# [1200 rows x 10 columns]

# %%
clus_2=data_1000[data_1000['number_cluster']==2]

# %%
clus_2
# Out:
#               function version            data  dependent  independent  \
# 0                  cct      v1  synthetic 1000          5            5
# 1                  cct      v1  synthetic 1000          5            5
# 2                  cct      v1  synthetic 1000          5            5
# 6                  cct      v1  synthetic 1000          5           10
# 7                  cct      v1  synthetic 1000          5           10
# ...                ...     ...             ...        ...          ...
# 1189  get_trends (sub)      v2  synthetic 1000         25           20
# 1190  get_trends (sub)      v2  synthetic 1000         25           20
# 1194  get_trends (sub)      v2  synthetic 1000         25           25
# 1195  get_trends (sub)      v2  synthetic 1000         25           25
# 1196  get_trends (sub)      v2  synthetic 1000         25           25
#
#       number_cluster  num_splitby      times  trial  dep:indep
# 0                  2            4   0.272983    4.5        0.0
# 1                  2            8   0.341954    4.5        0.0
# 2                  2           16   0.238793    4.5        0.0
# 6                  2            4   0.348398    4.5        5.0
# 7                  2            8   0.348789    4.5        5.0
# ...              ...          ...        ...    ...        ...
# 1189               2            8  15.619936    4.5       -5.0
# 1190               2           16  15.595304    4.5       -5.0
# 1194               2            4  19.294448    4.5        0.0
# 1195               2            8  19.477171    4.5        0.0
# 1196               2           16  19.674387    4.5        0.0
#
# [600 rows x 10 columns]

# %%
sns.relplot(data=clus_2, x='dep:indep', y='times', kind='line', col='function', hue='version', row='num_splitby')

# %%
splitby_4=data_1000[data_1000['num_splitby']==4]

# %%
sns.relplot(data=splitby_4, x='dep:indep', y='times', kind='line', col='function', hue='version', row='number_cluster')
