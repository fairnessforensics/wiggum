# %% [markdown]
# # A Classification Audit: ProPublica
#
# In first iteration, this will only work on datasets that already have two or more binary classification variables included.
#
# We will need additional metadata: role options of being predictions or ground truths.

# %%
import numpy as np
import pandas as pd
import wiggum as wg

# %% [markdown]
# First, we will need a dataset that we can work with

# %%
dataset = pd.read_csv('https://github.com/propublica/compas-analysis/raw/master/compas-scores-two-years.csv',
                      header=0).set_index('id')

# %%
def clean_compas(df):
    
    # Clean the compas dataset according to the description provided by ProPublica of their analysis. 
    # In the original notebook the authors state:

    # There are a number of reasons remove rows because of missing data:
        
        # If the charge date of a defendants Compas scored crime was not within 30 days from when the person was arrested, 
        # we assume that because of data quality reasons, that we do not have the right offense.

        # We coded the recidivist flag -- `is_recid` -- to be -1 if we could not find a compas case at all.

        # In a similar vein, ordinary traffic offenses -- those with a `c_charge_degree` of 'O' -- will not result in Jail time 
        # are removed (only two of them).
 
        # We filtered the underlying data from Broward county to include only those rows representing people who had either 
        # recidivated in two years, or had at least two years outside of a correctional facility.

    # ix is the index of variables we want to keep.
    # Remove entries with inconsistent arrest information.
    rows_start = len(df)
    ix = df['days_b_screening_arrest'] <= 30
    ix = (df['days_b_screening_arrest'] >= -30) & ix

    # remove entries entries where compas case could not be found.
    ix = (df['is_recid'] != -1) & ix

    # remove traffic offenses.
    ix = (df['c_charge_degree'] != "O") & ix

    # remove entries without available text scores.
    ix = (df['score_text'] != 'N/A') & ix

    # trim dataset
    df = df.loc[ix,:]

    # create new attribute "length of stay" with total jail time.
    df['length_of_stay'] = (pd.to_datetime(df['c_jail_out'])-pd.to_datetime(df['c_jail_in'])).apply(lambda x: x.days)

    # print number of rows
    print('Number of rows removed: '+str(rows_start - len(df)))
    # print list of features again
    print('Features: '+str(list(df)))
    return df

dataset = clean_compas(dataset)
# Out:
# Number of rows removed: 1042
# Features: ['name', 'first', 'last', 'compas_screening_date', 'sex', 'dob', 'age', 'age_cat', 'race', 'juv_fel_count', 'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count', 'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number', 'c_offense_date', 'c_arrest_date', 'c_days_from_compas', 'c_charge_degree', 'c_charge_desc', 'is_recid', 'r_case_number', 'r_charge_degree', 'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid', 'is_violent_recid', 'vr_case_number', 'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc', 'type_of_assessment', 'decile_score.1', 'score_text', 'screening_date', 'v_type_of_assessment', 'v_decile_score', 'v_score_text', 'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1', 'start', 'end', 'event', 'two_year_recid', 'length_of_stay']
# /home/smb/Documents/code/detect_simpsons_paradox_dev/env/lib/python3.6/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def corels_rule(row):
    return int(row['priors_count'] > 3 or (row['priors_count'] <=3 and row['age'] <=22))

dataset['corels'] = dataset.apply(corels_rule,axis=1)

# %%
dataset['decile_score_pred6'] = [int(ds>=6) for ds in dataset['decile_score']]
dataset['decile_score_pred7'] = [int(ds>=7) for ds in dataset['decile_score']]
dataset['decile_score_pred8'] = [int(ds>=8) for ds in dataset['decile_score']]
labeled_df = wg.LabeledDataFrame(dataset)

# %%
labeled_df.df.head()
# Out:
# variable              name   first       last compas_screening_date   sex  \
# id
# 1         miguel hernandez  miguel  hernandez            2013-08-14  Male
# 3              kevon dixon   kevon      dixon            2013-01-27  Male
# 4                 ed philo      ed      philo            2013-04-14  Male
# 7             marsha miles  marsha      miles            2013-11-30  Male
# 8            edward riddle  edward     riddle            2014-02-19  Male
#
# variable         dob  age          age_cat              race  juv_fel_count  \
# id
# 1         1947-04-18   69  Greater than 45             Other              0
# 3         1982-01-22   34          25 - 45  African-American              0
# 4         1991-05-14   24     Less than 25  African-American              0
# 7         1971-08-22   44          25 - 45             Other              0
# 8         1974-07-23   41          25 - 45         Caucasian              0
#
# variable  ...  priors_count.1  start  end  event  two_year_recid  \
# id        ...
# 1         ...               0      0  327      0               0
# 3         ...               0      9  159      1               1
# 4         ...               4      0   63      0               1
# 7         ...               0      1  853      0               0
# 8         ...              14      5   40      1               1
#
# variable length_of_stay corels decile_score_pred6 decile_score_pred7  \
# id
# 1                     0      0                  0                  0
# 3                    10      0                  0                  0
# 4                     1      1                  0                  0
# 7                     1      0                  0                  0
# 8                     6      1                  1                  0
#
# variable decile_score_pred8
# id
# 1                         0
# 3                         0
# 4                         0
# 7                         0
# 8                         0
#
# [5 rows x 57 columns]

# %% [markdown]
# To test, we need create additional decision columns, to make it interesting, we will make them correlated with the true decision and the race, gender or dept.
#
# We will start by modifying only the dataframe.  We will add the metadata and make a new labeled df after.

# %%
labeled_df.infer_var_types()
labeled_df.df.columns
# Out:
# Index(['name', 'first', 'last', 'compas_screening_date', 'sex', 'dob', 'age',
#        'age_cat', 'race', 'juv_fel_count', 'decile_score', 'juv_misd_count',
#        'juv_other_count', 'priors_count', 'days_b_screening_arrest',
#        'c_jail_in', 'c_jail_out', 'c_case_number', 'c_offense_date',
#        'c_arrest_date', 'c_days_from_compas', 'c_charge_degree',
#        'c_charge_desc', 'is_recid', 'r_case_number', 'r_charge_degree',
#        'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in',
#        'r_jail_out', 'violent_recid', 'is_violent_recid', 'vr_case_number',
#        'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc',
#        'type_of_assessment', 'decile_score.1', 'score_text', 'screening_date',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'v_screening_date', 'in_custody', 'out_custody', 'priors_count.1',
#        'start', 'end', 'event', 'two_year_recid', 'length_of_stay', 'corels',
#        'decile_score_pred6', 'decile_score_pred7', 'decile_score_pred8'],
#       dtype='object', name='variable')

# %%
labeled_df.df.dtypes
# Out:
# variable
# name                        object
# first                       object
# last                        object
# compas_screening_date       object
# sex                         object
# dob                         object
# age                          int64
# age_cat                     object
# race                        object
# juv_fel_count                int64
# decile_score                 int64
# juv_misd_count               int64
# juv_other_count              int64
# priors_count                 int64
# days_b_screening_arrest    float64
# c_jail_in                   object
# c_jail_out                  object
# c_case_number               object
# c_offense_date              object
# c_arrest_date               object
# c_days_from_compas         float64
# c_charge_degree             object
# c_charge_desc               object
# is_recid                     int64
# r_case_number               object
# r_charge_degree             object
# r_days_from_arrest         float64
# r_offense_date              object
# r_charge_desc               object
# r_jail_in                   object
# r_jail_out                  object
# violent_recid              float64
# is_violent_recid             int64
# vr_case_number              object
# vr_charge_degree            object
# vr_offense_date             object
# vr_charge_desc              object
# type_of_assessment          object
# decile_score.1               int64
# score_text                  object
# screening_date              object
# v_type_of_assessment        object
# v_decile_score               int64
# v_score_text                object
# v_screening_date            object
# in_custody                  object
# out_custody                 object
# priors_count.1               int64
# start                        int64
# end                          int64
# event                        int64
# two_year_recid               int64
# length_of_stay               int64
# corels                       int64
# decile_score_pred6           int64
# decile_score_pred7           int64
# decile_score_pred8           int64
# dtype: object

# %%
labeled_df.df.head()
# Out:
# variable              name   first       last compas_screening_date   sex  \
# id
# 1         miguel hernandez  miguel  hernandez            2013-08-14  Male
# 3              kevon dixon   kevon      dixon            2013-01-27  Male
# 4                 ed philo      ed      philo            2013-04-14  Male
# 7             marsha miles  marsha      miles            2013-11-30  Male
# 8            edward riddle  edward     riddle            2014-02-19  Male
#
# variable         dob  age          age_cat              race  juv_fel_count  \
# id
# 1         1947-04-18   69  Greater than 45             Other              0
# 3         1982-01-22   34          25 - 45  African-American              0
# 4         1991-05-14   24     Less than 25  African-American              0
# 7         1971-08-22   44          25 - 45             Other              0
# 8         1974-07-23   41          25 - 45         Caucasian              0
#
# variable  ...  priors_count.1  start  end  event  two_year_recid  \
# id        ...
# 1         ...               0      0  327      0               0
# 3         ...               0      9  159      1               1
# 4         ...               4      0   63      0               1
# 7         ...               0      1  853      0               0
# 8         ...              14      5   40      1               1
#
# variable length_of_stay corels decile_score_pred6 decile_score_pred7  \
# id
# 1                     0      0                  0                  0
# 3                    10      0                  0                  0
# 4                     1      1                  0                  0
# 7                     1      0                  0                  0
# 8                     6      1                  1                  0
#
# variable decile_score_pred8
# id
# 1                         0
# 3                         0
# 4                         0
# 7                         0
# 8                         0
#
# [5 rows x 57 columns]

# %%
roles = {'name':'ignore', 'first':'ignore', 'last':'ignore', 'compas_screening_date':'ignore', 
         'sex':['groupby', 'trend'], 'dob':'ignore', 'age':'trend',
       'age_cat':['groupby', 'trend'], 'race':['groupby', 'trend'], 'juv_fel_count':'ignore', 
         'decile_score':'trend', 'juv_misd_count':'ignore',
       'juv_other_count': 'ignore', 'priors_count': 'trend', 'days_b_screening_arrest':'ignore',
       'c_jail_in':'ignore', 'c_jail_out':'ignore', 'c_case_number':'ignore', 'c_offense_date':'ignore',
       'c_arrest_date':'ignore', 'c_days_from_compas':'ignore', 'c_charge_degree':'ignore',
       'c_charge_desc':'ignore', 'is_recid':'ignore', 'r_case_number':'ignore', 'r_charge_degree':'ignore',
       'r_days_from_arrest':'ignore', 'r_offense_date':'ignore', 'r_charge_desc':'ignore', 'r_jail_in':'ignore',
       'r_jail_out':'ignore', 'violent_recid':'ignore', 'is_violent_recid':'ignore',
         'vr_case_number':'ignore',
       'vr_charge_degree':'ignore', 'vr_offense_date':'ignore', 'vr_charge_desc':'ignore',
       'type_of_assessment':'groupby', 'decile_score.1':'trend', 'score_text':'groupby', 'screening_date':'ignore',
       'v_type_of_assessment':'groupby', 'v_decile_score':'trend', 'v_score_text':'ignore',
       'v_screening_date':'ignore', 'in_custody':'ignore', 'out_custody':'ignore', 'priors_count.1':'ignore',
       'start':'ignore', 'end':'ignore', 'event':'ignore', 'two_year_recid':['trend','groundtruth'],
        'decile_score_pred6':['trend','prediction'],'decile_score_pred7':['trend','prediction'],
         'decile_score_pred8':['trend','prediction'],'corels':['trend','prediction'],'length_of_stay':'ignore'}
var_types = {'sex':'categorical','age':'continuous'}
# is_count = {c:False for c in test_df.columns}


labeled_df.set_roles(roles)
labeled_df.set_var_types(var_types)
labeled_df.meta_df
# Out:
#                            dtype     var_type                  role isCount  \
# variable
# name                      object  categorical                ignore     NaN
# first                     object  categorical                ignore     NaN
# last                      object  categorical                ignore     NaN
# compas_screening_date     object  categorical                ignore     NaN
# sex                       object  categorical      [groupby, trend]     NaN
# dob                       object  categorical                ignore     NaN
# age                        int64   continuous                 trend     NaN
# age_cat                   object  categorical      [groupby, trend]     NaN
# race                      object  categorical      [groupby, trend]     NaN
# juv_fel_count              int64      ordinal                ignore     NaN
# decile_score               int64      ordinal                 trend     NaN
# juv_misd_count             int64      ordinal                ignore     NaN
# juv_other_count            int64      ordinal                ignore     NaN
# priors_count               int64      ordinal                 trend     NaN
# days_b_screening_arrest  float64   continuous                ignore     NaN
# c_jail_in                 object  categorical                ignore     NaN
# c_jail_out                object  categorical                ignore     NaN
# c_case_number             object  categorical                ignore     NaN
# c_offense_date            object  categorical                ignore     NaN
# c_arrest_date             object  categorical                ignore     NaN
# c_days_from_compas       float64   continuous                ignore     NaN
# c_charge_degree           object       binary                ignore     NaN
# c_charge_desc             object  categorical                ignore     NaN
# is_recid                   int64       binary                ignore     NaN
# r_case_number             object  categorical                ignore     NaN
# r_charge_degree           object  categorical                ignore     NaN
# r_days_from_arrest       float64   continuous                ignore     NaN
# r_offense_date            object  categorical                ignore     NaN
# r_charge_desc             object  categorical                ignore     NaN
# r_jail_in                 object  categorical                ignore     NaN
# r_jail_out                object  categorical                ignore     NaN
# violent_recid            float64   continuous                ignore     NaN
# is_violent_recid           int64       binary                ignore     NaN
# vr_case_number            object  categorical                ignore     NaN
# vr_charge_degree          object  categorical                ignore     NaN
# vr_offense_date           object  categorical                ignore     NaN
# vr_charge_desc            object  categorical                ignore     NaN
# type_of_assessment        object  categorical               groupby     NaN
# decile_score.1             int64      ordinal                 trend     NaN
# score_text                object  categorical               groupby     NaN
# screening_date            object  categorical                ignore     NaN
# v_type_of_assessment      object  categorical               groupby     NaN
# v_decile_score             int64      ordinal                 trend     NaN
# v_score_text              object  categorical                ignore     NaN
# v_screening_date          object  categorical                ignore     NaN
# in_custody                object  categorical                ignore     NaN
# out_custody               object  categorical                ignore     NaN
# priors_count.1             int64      ordinal                ignore     NaN
# start                      int64      ordinal                ignore     NaN
# end                        int64      ordinal                ignore     NaN
# event                      int64       binary                ignore     NaN
# two_year_recid             int64       binary  [trend, groundtruth]     NaN
# length_of_stay             int64      ordinal                ignore     NaN
# corels                     int64       binary   [trend, prediction]     NaN
# decile_score_pred6         int64       binary   [trend, prediction]     NaN
# decile_score_pred7         int64       binary   [trend, prediction]     NaN
# decile_score_pred8         int64       binary   [trend, prediction]     NaN
#
#                         weighting_var
# variable
# name                              NaN
# first                             NaN
# last                              NaN
# compas_screening_date             NaN
# sex                               NaN
# dob                               NaN
# age                               NaN
# age_cat                           NaN
# race                              NaN
# juv_fel_count                     NaN
# decile_score                      NaN
# juv_misd_count                    NaN
# juv_other_count                   NaN
# priors_count                      NaN
# days_b_screening_arrest           NaN
# c_jail_in                         NaN
# c_jail_out                        NaN
# c_case_number                     NaN
# c_offense_date                    NaN
# c_arrest_date                     NaN
# c_days_from_compas                NaN
# c_charge_degree                   NaN
# c_charge_desc                     NaN
# is_recid                          NaN
# r_case_number                     NaN
# r_charge_degree                   NaN
# r_days_from_arrest                NaN
# r_offense_date                    NaN
# r_charge_desc                     NaN
# r_jail_in                         NaN
# r_jail_out                        NaN
# violent_recid                     NaN
# is_violent_recid                  NaN
# vr_case_number                    NaN
# vr_charge_degree                  NaN
# vr_offense_date                   NaN
# vr_charge_desc                    NaN
# type_of_assessment                NaN
# decile_score.1                    NaN
# score_text                        NaN
# screening_date                    NaN
# v_type_of_assessment              NaN
# v_decile_score                    NaN
# v_score_text                      NaN
# v_screening_date                  NaN
# in_custody                        NaN
# out_custody                       NaN
# priors_count.1                    NaN
# start                             NaN
# end                               NaN
# event                             NaN
# two_year_recid                    NaN
# length_of_stay                    NaN
# corels                            NaN
# decile_score_pred6                NaN
# decile_score_pred7                NaN
# decile_score_pred8                NaN

# %%
labeled_df.to_csvs('../data/propublica_multi/')

# %%
labeled_df.add_intersectional(var_list = ['race','sex','age_cat'])
# Out:
# variable                 name      first       last compas_screening_date  \
# id
# 1            miguel hernandez     miguel  hernandez            2013-08-14
# 3                 kevon dixon      kevon      dixon            2013-01-27
# 4                    ed philo         ed      philo            2013-04-14
# 7                marsha miles     marsha      miles            2013-11-30
# 8               edward riddle     edward     riddle            2014-02-19
# ...                       ...        ...        ...                   ...
# 10996           steven butler     steven     butler            2013-11-23
# 10997         malcolm simmons    malcolm    simmons            2014-02-01
# 10999         winston gregory    winston    gregory            2014-01-14
# 11000             farrah jean     farrah       jean            2014-03-09
# 11001     florencia sanmartin  florencia  sanmartin            2014-06-30
#
# variable     sex         dob  age          age_cat              race  \
# id
# 1           Male  1947-04-18   69  Greater than 45             Other
# 3           Male  1982-01-22   34          25 - 45  African-American
# 4           Male  1991-05-14   24     Less than 25  African-American
# 7           Male  1971-08-22   44          25 - 45             Other
# 8           Male  1974-07-23   41          25 - 45         Caucasian
# ...          ...         ...  ...              ...               ...
# 10996       Male  1992-07-17   23     Less than 25  African-American
# 10997       Male  1993-03-25   23     Less than 25  African-American
# 10999       Male  1958-10-01   57  Greater than 45             Other
# 11000     Female  1982-11-17   33          25 - 45  African-American
# 11001     Female  1992-12-18   23     Less than 25          Hispanic
#
# variable  juv_fel_count  ...  event  two_year_recid  length_of_stay  corels  \
# id                       ...
# 1                     0  ...      0               0               0       0
# 3                     0  ...      1               1              10       0
# 4                     0  ...      0               1               1       1
# 7                     0  ...      0               0               1       0
# 8                     0  ...      1               1               6       1
# ...                 ...  ...    ...             ...             ...     ...
# 10996                 0  ...      0               0               1       0
# 10997                 0  ...      0               0               1       0
# 10999                 0  ...      0               0               1       0
# 11000                 0  ...      0               0               1       0
# 11001                 0  ...      0               1               1       0
#
# variable  decile_score_pred6 decile_score_pred7 decile_score_pred8  \
# id
# 1                          0                  0                  0
# 3                          0                  0                  0
# 4                          0                  0                  0
# 7                          0                  0                  0
# 8                          1                  0                  0
# ...                      ...                ...                ...
# 10996                      1                  1                  0
# 10997                      0                  0                  0
# 10999                      0                  0                  0
# 11000                      0                  0                  0
# 11001                      0                  0                  0
#
# variable                 race_sex                   race_age_cat  \
# id
# 1                      Other_Male          Other_Greater than 45
# 3           African-American_Male       African-American_25 - 45
# 4           African-American_Male  African-American_Less than 25
# 7                      Other_Male                  Other_25 - 45
# 8                  Caucasian_Male              Caucasian_25 - 45
# ...                           ...                            ...
# 10996       African-American_Male  African-American_Less than 25
# 10997       African-American_Male  African-American_Less than 25
# 10999                  Other_Male          Other_Greater than 45
# 11000     African-American_Female       African-American_25 - 45
# 11001             Hispanic_Female          Hispanic_Less than 25
#
# variable           sex_age_cat
# id
# 1         Male_Greater than 45
# 3                 Male_25 - 45
# 4            Male_Less than 25
# 7                 Male_25 - 45
# 8                 Male_25 - 45
# ...                        ...
# 10996        Male_Less than 25
# 10997        Male_Less than 25
# 10999     Male_Greater than 45
# 11000           Female_25 - 45
# 11001      Female_Less than 25
#
# [6172 rows x 60 columns]

# %%
acc_trend = wg.Binary_Accuracy_Trend()
tpr_trend = wg.Binary_TPR_Trend()
ppv_trend = wg.Binary_PPV_Trend()
tnr_trend = wg.Binary_TNR_Trend()
fdr_trend = wg.Binary_FDR_Trend()
fnr_trend = wg.Binary_FNR_Trend()
err_trend = wg.Binary_Error_Trend()
f1_trend = wg.Binary_F1_Trend()
labeled_df.get_pairwise_trends_1lev([acc_trend,tpr_trend,ppv_trend,
                                    tnr_trend,fdr_trend,f1_trend,
                                    fnr_trend,err_trend],replace=True)
# Out:
# /home/smb/Documents/code/detect_simpsons_paradox_dev/env/lib/python3.6/site-packages/wiggum/trend_components/classification.py:13: RuntimeWarning: invalid value encountered in long_scalars
#   'ppv': lambda c: c['TP']/(c['TP'] + c['FP']),
# /home/smb/Documents/code/detect_simpsons_paradox_dev/env/lib/python3.6/site-packages/wiggum/trend_components/classification.py:15: RuntimeWarning: invalid value encountered in long_scalars
#   'tnr': lambda c: c['TN']/(c['TN'] + c['FP']),
# /home/smb/Documents/code/detect_simpsons_paradox_dev/env/lib/python3.6/site-packages/wiggum/trend_components/classification.py:16: RuntimeWarning: invalid value encountered in long_scalars
#   'fdr': lambda c: c['FP']/(c['TP'] + c['FP']),
# Index(['feat1', 'feat2', 'subgroup_trend', 'subgroup',
#        'subgroup_trend_strength', 'group_feat', 'trend_type'],
#       dtype='object')
# Index(['feat1', 'feat2', 'group_feat', 'subgroup', 'subgroup_trend',
#        'subgroup_trend_strength', 'trend_type'],
#       dtype='object')
# 1664
# 18048
# Index(['feat1', 'feat2', 'group_feat', 'subgroup', 'subgroup_trend',
#        'subgroup_trend_strength', 'trend_type', 'subgroup2', 'subgroup_trend2',
#        'subgroup_trend_strength2'],
#       dtype='object')
# 8192
# 7870
#                 feat1               feat2   group_feat              subgroup  \
# 1      two_year_recid              corels          sex                Female
# 5      two_year_recid  decile_score_pred6          sex                Female
# 9      two_year_recid  decile_score_pred7          sex                Female
# 13     two_year_recid  decile_score_pred8          sex                Female
# 17     two_year_recid              corels      age_cat               25 - 45
# ...               ...                 ...          ...                   ...
# 18028  two_year_recid  decile_score_pred8  sex_age_cat   Female_Less than 25
# 18029  two_year_recid  decile_score_pred8  sex_age_cat   Female_Less than 25
# 18034  two_year_recid  decile_score_pred8  sex_age_cat          Male_25 - 45
# 18035  two_year_recid  decile_score_pred8  sex_age_cat          Male_25 - 45
# 18041  two_year_recid  decile_score_pred8  sex_age_cat  Male_Greater than 45
#
#        subgroup_trend  subgroup_trend_strength  trend_type  \
# 1            0.677447                 0.674271  binary_acc
# 5            0.683404                 0.674271  binary_acc
# 9            0.688511                 0.674271  binary_acc
# 13           0.686809                 0.674271  binary_acc
# 17           0.672707                 0.718153  binary_acc
# ...               ...                      ...         ...
# 18028        0.341463                 0.581754  binary_err
# 18029        0.341463                 0.581754  binary_err
# 18034        0.377770                 0.710462  binary_err
# 18035        0.377770                 0.710462  binary_err
# 18041        0.303894                 0.669140  binary_err
#
#                   subgroup2  subgroup_trend2  subgroup_trend_strength2  \
# 1                      Male         0.660997                  0.729635
# 5                      Male         0.659796                  0.729635
# 9                      Male         0.641185                  0.729635
# 13                     Male         0.621573                  0.729635
# 17          Greater than 45         0.709977                  0.678622
# ...                     ...              ...                       ...
# 18028  Male_Greater than 45         0.303894                  0.669140
# 18029     Male_Less than 25         0.451408                  0.671246
# 18034  Male_Greater than 45         0.303894                  0.669140
# 18035     Male_Less than 25         0.451408                  0.671246
# 18041     Male_Less than 25         0.451408                  0.671246
#
#       comparison_type
# 1            pairwise
# 5            pairwise
# 9            pairwise
# 13           pairwise
# 17           pairwise
# ...               ...
# 18028        pairwise
# 18029        pairwise
# 18034        pairwise
# 18035        pairwise
# 18041        pairwise
#
# [7870 rows x 11 columns]

# %%
len(labeled_df.result_df)
# Out:
# 7870

# %%
labeled_df.get_trend_rows(trend_type='binary_tnr')
# Out:
# 848  total rows meet the criteria
#                feat1               feat2   group_feat              subgroup  \
# 6769  two_year_recid              corels          sex                Female
# 6773  two_year_recid  decile_score_pred6          sex                Female
# 6777  two_year_recid  decile_score_pred7          sex                Female
# 6781  two_year_recid  decile_score_pred8          sex                Female
# 6785  two_year_recid              corels      age_cat               25 - 45
# ...              ...                 ...          ...                   ...
# 9004  two_year_recid  decile_score_pred8  sex_age_cat   Female_Less than 25
# 9005  two_year_recid  decile_score_pred8  sex_age_cat   Female_Less than 25
# 9010  two_year_recid  decile_score_pred8  sex_age_cat          Male_25 - 45
# 9011  two_year_recid  decile_score_pred8  sex_age_cat          Male_25 - 45
# 9017  two_year_recid  decile_score_pred8  sex_age_cat  Male_Greater than 45
#
#       subgroup_trend  subgroup_trend_strength  trend_type  \
# 6769        0.795276                 0.674271  binary_tnr
# 6773        0.797900                 0.674271  binary_tnr
# 6777        0.876640                 0.674271  binary_tnr
# 6781        0.930446                 0.674271  binary_tnr
# 6785        0.790058                 0.718153  binary_tnr
# ...              ...                      ...         ...
# 9004        0.856209                 0.581754  binary_tnr
# 9005        0.856209                 0.581754  binary_tnr
# 9010        0.903623                 0.710462  binary_tnr
# 9011        0.903623                 0.710462  binary_tnr
# 9017        0.971347                 0.669140  binary_tnr
#
#                  subgroup2  subgroup_trend2  subgroup_trend_strength2  \
# 6769                  Male         0.716263                  0.729635
# 6773                  Male         0.783929                  0.729635
# 6777                  Male         0.845829                  0.729635
# 6781                  Male         0.906190                  0.729635
# 6785       Greater than 45         0.796359                  0.678622
# ...                    ...              ...                       ...
# 9004  Male_Greater than 45         0.971347                  0.669140
# 9005     Male_Less than 25         0.811364                  0.671246
# 9010  Male_Greater than 45         0.971347                  0.669140
# 9011     Male_Less than 25         0.811364                  0.671246
# 9017     Male_Less than 25         0.811364                  0.671246
#
#      comparison_type  distance
# 6769        pairwise  0.079013
# 6773        pairwise  0.013971
# 6777        pairwise  0.030812
# 6781        pairwise  0.024256
# 6785        pairwise  0.006301
# ...              ...       ...
# 9004        pairwise  0.115138
# 9005        pairwise  0.044846
# 9010        pairwise  0.067724
# 9011        pairwise  0.092259
# 9017        pairwise  0.159983
#
# [848 rows x 12 columns]

# %%
labeled_df.get_trend_rows('two_year_recid','decile_score_pred6','race')
# Out:
# 120  total rows meet the criteria
#                 feat1               feat2 group_feat          subgroup  \
# 89     two_year_recid  decile_score_pred6       race  African-American
# 90     two_year_recid  decile_score_pred6       race  African-American
# 91     two_year_recid  decile_score_pred6       race  African-American
# 92     two_year_recid  decile_score_pred6       race  African-American
# 93     two_year_recid  decile_score_pred6       race  African-American
# ...               ...                 ...        ...               ...
# 15896  two_year_recid  decile_score_pred6       race         Caucasian
# 15897  two_year_recid  decile_score_pred6       race         Caucasian
# 15902  two_year_recid  decile_score_pred6       race          Hispanic
# 15903  two_year_recid  decile_score_pred6       race          Hispanic
# 15909  two_year_recid  decile_score_pred6       race   Native American
#
#        subgroup_trend  subgroup_trend_strength  trend_type        subgroup2  \
# 89           0.651339                 0.714428  binary_acc            Asian
# 90           0.651339                 0.714428  binary_acc        Caucasian
# 91           0.651339                 0.714428  binary_acc         Hispanic
# 92           0.651339                 0.714428  binary_acc  Native American
# 93           0.651339                 0.714428  binary_acc            Other
# ...               ...                      ...         ...              ...
# 15896        0.319544                 0.699053  binary_err  Native American
# 15897        0.319544                 0.699053  binary_err            Other
# 15902        0.339882                 0.630549  binary_err  Native American
# 15903        0.339882                 0.630549  binary_err            Other
# 15909        0.272727                 0.039747  binary_err            Other
#
#        subgroup_trend2  subgroup_trend_strength2 comparison_type
# 89            0.806452                  0.329472        pairwise
# 90            0.680456                  0.699053        pairwise
# 91            0.660118                  0.630549        pairwise
# 92            0.727273                  0.039747        pairwise
# 93            0.676385                  0.605568        pairwise
# ...                ...                       ...             ...
# 15896         0.272727                  0.039747        pairwise
# 15897         0.323615                  0.605568        pairwise
# 15902         0.272727                  0.039747        pairwise
# 15903         0.323615                  0.605568        pairwise
# 15909         0.323615                  0.605568        pairwise
#
# [120 rows x 11 columns]

# %%
labeled_df.add_distance('subgroup','subgroup2',True)

# %%
labeled_df.get_trend_rows(subgroup='African-American',subgroup2='Caucasian',trend_type='binary_tnr').sort_values(by='distance',ascending=False)
# Out:
# 4  total rows meet the criteria
#                feat1               feat2 group_feat          subgroup  \
# 6858  two_year_recid  decile_score_pred6       race  African-American
# 6822  two_year_recid              corels       race  African-American
# 6894  two_year_recid  decile_score_pred7       race  African-American
# 6930  two_year_recid  decile_score_pred8       race  African-American
#
#       subgroup_trend  subgroup_trend_strength  trend_type  subgroup2  \
# 6858        0.685601                 0.714428  binary_tnr  Caucasian
# 6822        0.638705                 0.714428  binary_tnr  Caucasian
# 6894        0.772127                 0.714428  binary_tnr  Caucasian
# 6930        0.860634                 0.714428  binary_tnr  Caucasian
#
#       subgroup_trend2  subgroup_trend_strength2 comparison_type  distance
# 6858         0.864949                  0.699053        pairwise  0.179348
# 6822         0.803279                  0.699053        pairwise  0.164573
# 6894         0.917252                  0.699053        pairwise  0.145125
# 6930         0.952381                  0.699053        pairwise  0.091747

# %%
labeled_df.get_trend_rows(subgroup='Caucasian')
# Out:
# 96  total rows meet the criteria
#                 feat1               feat2 group_feat   subgroup  \
# 67     two_year_recid              corels       race  Caucasian
# 68     two_year_recid              corels       race  Caucasian
# 69     two_year_recid              corels       race  Caucasian
# 103    two_year_recid  decile_score_pred6       race  Caucasian
# 104    two_year_recid  decile_score_pred6       race  Caucasian
# ...               ...                 ...        ...        ...
# 15932  two_year_recid  decile_score_pred7       race  Caucasian
# 15933  two_year_recid  decile_score_pred7       race  Caucasian
# 15967  two_year_recid  decile_score_pred8       race  Caucasian
# 15968  two_year_recid  decile_score_pred8       race  Caucasian
# 15969  two_year_recid  decile_score_pred8       race  Caucasian
#
#        subgroup_trend  subgroup_trend_strength  trend_type        subgroup2  \
# 67           0.667618                 0.699053  binary_acc         Hispanic
# 68           0.667618                 0.699053  binary_acc  Native American
# 69           0.667618                 0.699053  binary_acc            Other
# 103          0.680456                 0.699053  binary_acc         Hispanic
# 104          0.680456                 0.699053  binary_acc  Native American
# ...               ...                      ...         ...              ...
# 15932        0.331907                 0.699053  binary_err  Native American
# 15933        0.331907                 0.699053  binary_err            Other
# 15967        0.342844                 0.699053  binary_err         Hispanic
# 15968        0.342844                 0.699053  binary_err  Native American
# 15969        0.342844                 0.699053  binary_err            Other
#
#        subgroup_trend2  subgroup_trend_strength2 comparison_type  distance
# 67            0.689587                  0.630549        pairwise  0.021970
# 68            0.909091                  0.039747        pairwise  0.241473
# 69            0.725948                  0.605568        pairwise  0.058330
# 103           0.660118                  0.630549        pairwise  0.020339
# 104           0.727273                  0.039747        pairwise  0.046816
# ...                ...                       ...             ...       ...
# 15932         0.272727                  0.039747        pairwise  0.059180
# 15933         0.311953                  0.605568        pairwise  0.019953
# 15967         0.357564                  0.630549        pairwise  0.014720
# 15968         0.272727                  0.039747        pairwise  0.070116
# 15969         0.314869                  0.605568        pairwise  0.027975
#
# [96 rows x 12 columns]

# %%
labeled_df.df['two_year_recid_decile_score_pred6_acc'].value_counts()
# Out:
# TN    2647
# TP    1453
# FN    1356
# FP     716
# Name: two_year_recid_decile_score_pred6_acc, dtype: int64
