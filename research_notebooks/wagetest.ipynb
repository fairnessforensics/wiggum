# %%
import pandas as pd
import os
import wiggum as wg
import numpy as np
import itertools

# %%
labeled_df = wg.LabeledDataFrame('../data/wages_gender_rank_time_regression2/')

# %%
labeled_df.meta_df
# Out:
#               dtype     var_type                      role  isCount  \
# variable
# pay         float64   continuous  [independent, dependent]    False
# year        float64   continuous  [independent, dependent]    False
# department   object  categorical    [independent, splitby]    False
# gender       object  categorical    [independent, splitby]    False
#
#             weighting_var
# variable
# pay                   NaN
# year                  NaN
# department            NaN
# gender                NaN

# %%
corrobj = wg.All_Pearson()
corrobj.get_trend_vars(labeled_df)
corrobj.regression_vars
# Out:
# [('pay', 'year'), ('year', 'pay')]

# %%
corrobj.symmetric_vars
# Out:
# True

# %%
labeled_df.get_subgroup_trends_1lev([corrobj])
labeled_df.result_df
# Out:
#   dependent  group_feat independent    subgroup  subgroup_trend  \
# 0      year  department         pay  Management       -0.179974
# 1      year  department         pay         R&D       -0.711535
# 2      year  department         pay       Sales       -0.730384
# 3      year  department         pay     Support       -0.806535
# 4      year      gender         pay           F        0.019400
# 5      year      gender         pay           M        0.053508
#
#    subgroup_trend_strength    trend_type  agg_trend  agg_trend_strength  \
# 0                 0.179974  pearson_corr   0.039252            0.039252
# 1                 0.711535  pearson_corr   0.039252            0.039252
# 2                 0.730384  pearson_corr   0.039252            0.039252
# 3                 0.806535  pearson_corr   0.039252            0.039252
# 4                 0.019400  pearson_corr   0.039252            0.039252
# 5                 0.053508  pearson_corr   0.039252            0.039252
#
#       comparison_type
# 0  aggregate-subgroup
# 1  aggregate-subgroup
# 2  aggregate-subgroup
# 3  aggregate-subgroup
# 4  aggregate-subgroup
# 5  aggregate-subgroup

# %%
linreg_obj = wg.All_Linear_Trend()
labeled_df.get_subgroup_trends_1lev([corrobj,linreg_obj], replace=True)
# Out:
#    dependent  group_feat independent    subgroup  subgroup_trend  \
# 0        pay  department        year  Management       -0.179974
# 1        pay  department        year  Management       -0.179974
# 2        pay  department        year         R&D       -0.711535
# 3        pay  department        year         R&D       -0.711535
# 4        pay  department        year       Sales       -0.730384
# 5        pay  department        year       Sales       -0.730384
# 6        pay  department        year     Support       -0.806535
# 7        pay  department        year     Support       -0.806535
# 8        pay      gender        year           F        0.019400
# 9        pay      gender        year           F        0.019400
# 10       pay      gender        year           M        0.053508
# 11       pay      gender        year           M        0.053508
# 12       pay  department        year  Management       -0.179974
# 13       pay  department        year  Management       -0.179974
# 14       pay  department        year         R&D       -0.711535
# 15       pay  department        year         R&D       -0.711535
# 16       pay  department        year       Sales       -0.730384
# 17       pay  department        year       Sales       -0.730384
# 18       pay  department        year     Support       -0.806535
# 19       pay  department        year     Support       -0.806535
# 20       pay      gender        year           F        0.019400
# 21       pay      gender        year           F        0.019400
# 22       pay      gender        year           M        0.053508
# 23       pay      gender        year           M        0.053508
# 24      year  department         pay  Management       -2.226435
# 25      year  department         pay         R&D       -6.786051
# 26      year  department         pay       Sales       -6.230426
# 27      year  department         pay     Support       -6.396643
# 28      year      gender         pay           F        0.028546
# 29      year      gender         pay           M        0.078698
# 30       pay  department        year  Management       -0.014548
# 31       pay  department        year         R&D       -0.074606
# 32       pay  department        year       Sales       -0.085622
# 33       pay  department        year     Support       -0.101694
# 34       pay      gender        year           F        0.013185
# 35       pay      gender        year           M        0.036380
#
#     subgroup_trend_strength    trend_type  agg_trend  agg_trend_strength  \
# 0                  0.179974  pearson_corr   0.039252            0.039252
# 1                  0.179974  pearson_corr   0.039252            0.039252
# 2                  0.711535  pearson_corr   0.039252            0.039252
# 3                  0.711535  pearson_corr   0.039252            0.039252
# 4                  0.730384  pearson_corr   0.039252            0.039252
# 5                  0.730384  pearson_corr   0.039252            0.039252
# 6                  0.806535  pearson_corr   0.039252            0.039252
# 7                  0.806535  pearson_corr   0.039252            0.039252
# 8                  0.019400  pearson_corr   0.039252            0.039252
# 9                  0.019400  pearson_corr   0.039252            0.039252
# 10                 0.053508  pearson_corr   0.039252            0.039252
# 11                 0.053508  pearson_corr   0.039252            0.039252
# 12                 0.179974  pearson_corr   0.039252            0.039252
# 13                 0.179974  pearson_corr   0.039252            0.039252
# 14                 0.711535  pearson_corr   0.039252            0.039252
# 15                 0.711535  pearson_corr   0.039252            0.039252
# 16                 0.730384  pearson_corr   0.039252            0.039252
# 17                 0.730384  pearson_corr   0.039252            0.039252
# 18                 0.806535  pearson_corr   0.039252            0.039252
# 19                 0.806535  pearson_corr   0.039252            0.039252
# 20                 0.019400  pearson_corr   0.039252            0.039252
# 21                 0.019400  pearson_corr   0.039252            0.039252
# 22                 0.053508  pearson_corr   0.039252            0.039252
# 23                 0.053508  pearson_corr   0.039252            0.039252
# 24                 0.179974       lin_reg   0.056930            0.039252
# 25                 0.711535       lin_reg   0.056930            0.039252
# 26                 0.730384       lin_reg   0.056930            0.039252
# 27                 0.806535       lin_reg   0.056930            0.039252
# 28                 0.019400       lin_reg   0.056930            0.039252
# 29                 0.053508       lin_reg   0.056930            0.039252
# 30                 0.179974       lin_reg   0.027063            0.039252
# 31                 0.711535       lin_reg   0.027063            0.039252
# 32                 0.730384       lin_reg   0.027063            0.039252
# 33                 0.806535       lin_reg   0.027063            0.039252
# 34                 0.019400       lin_reg   0.027063            0.039252
# 35                 0.053508       lin_reg   0.027063            0.039252
#
#        comparison_type
# 0   aggregate-subgroup
# 1   aggregate-subgroup
# 2   aggregate-subgroup
# 3   aggregate-subgroup
# 4   aggregate-subgroup
# 5   aggregate-subgroup
# 6   aggregate-subgroup
# 7   aggregate-subgroup
# 8   aggregate-subgroup
# 9   aggregate-subgroup
# 10  aggregate-subgroup
# 11  aggregate-subgroup
# 12  aggregate-subgroup
# 13  aggregate-subgroup
# 14  aggregate-subgroup
# 15  aggregate-subgroup
# 16  aggregate-subgroup
# 17  aggregate-subgroup
# 18  aggregate-subgroup
# 19  aggregate-subgroup
# 20  aggregate-subgroup
# 21  aggregate-subgroup
# 22  aggregate-subgroup
# 23  aggregate-subgroup
# 24  aggregate-subgroup
# 25  aggregate-subgroup
# 26  aggregate-subgroup
# 27  aggregate-subgroup
# 28  aggregate-subgroup
# 29  aggregate-subgroup
# 30  aggregate-subgroup
# 31  aggregate-subgroup
# 32  aggregate-subgroup
# 33  aggregate-subgroup
# 34  aggregate-subgroup
# 35  aggregate-subgroup

# %% [markdown]
# # Test diff setttings

# %%
labeled_df2 = wg.LabeledDataFrame('../data/iristest')
labeled_df2.meta_df
# Out:
#                 dtype     var_type                      role  isCount  \
# variable
# sepal length  float64   continuous  [independent, dependent]    False
# sepal width   float64   continuous               [dependent]    False
# petal length  float64   continuous             [independent]    False
# petal width   float64   continuous             [independent]    False
# class          object  categorical                 [splitby]    False
#
#               weighting_var
# variable
# sepal length            NaN
# sepal width             NaN
# petal length            NaN
# petal width             NaN
# class                   NaN

# %%
corr_vars = ['petal length', 'sepal length', 'petal width', 'sepal width']
labeled_df2.set_roles({v:['independent','dependent'] for v in corr_vars})

labeled_df2.meta_df
# Out:
# /home/smb/anaconda3/lib/python3.6/site-packages/wiggum/labeled_dataframe.py:365: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.meta_df['role'][k] = v
#                 dtype     var_type                      role  isCount  \
# variable
# sepal length  float64   continuous  [independent, dependent]    False
# sepal width   float64   continuous  [independent, dependent]    False
# petal length  float64   continuous  [independent, dependent]    False
# petal width   float64   continuous  [independent, dependent]    False
# class          object  categorical                 [splitby]    False
#
#               weighting_var
# variable
# sepal length            NaN
# sepal width             NaN
# petal length            NaN
# petal width             NaN
# class                   NaN

# %%
linreg_obj2 = wg.All_Linear_Trend()
labeled_df2.get_subgroup_trends_1lev([linreg_obj2], replace=True)
# Out:
#        dependent group_feat   independent         subgroup  subgroup_trend  \
# 0    sepal width      class  sepal length      Iris-setosa        0.807234
# 1    sepal width      class  sepal length  Iris-versicolor        0.319719
# 2    sepal width      class  sepal length   Iris-virginica        0.231890
# 3   petal length      class  sepal length      Iris-setosa        0.129891
# 4   petal length      class  sepal length  Iris-versicolor        0.686470
# 5   petal length      class  sepal length   Iris-virginica        0.750081
# 6    petal width      class  sepal length      Iris-setosa        0.084886
# 7    petal width      class  sepal length  Iris-versicolor        0.209357
# 8    petal width      class  sepal length   Iris-virginica        0.121416
# 9   sepal length      class   sepal width      Iris-setosa        0.690854
# 10  sepal length      class   sepal width  Iris-versicolor        0.865078
# 11  sepal length      class   sepal width   Iris-virginica        0.901534
# 12  petal length      class   sepal width      Iris-setosa        0.080463
# 13  petal length      class   sepal width  Iris-versicolor        0.839378
# 14  petal length      class   sepal width   Iris-virginica        0.686315
# 15   petal width      class   sepal width      Iris-setosa        0.078776
# 16   petal width      class   sepal width  Iris-versicolor        0.418446
# 17   petal width      class   sepal width   Iris-virginica        0.457949
# 18  sepal length      class  petal length      Iris-setosa        0.536063
# 19  sepal length      class  petal length  Iris-versicolor        0.828281
# 20  sepal length      class  petal length   Iris-virginica        0.995739
# 21   sepal width      class  petal length      Iris-setosa        0.388015
# 22   sepal width      class  petal length  Iris-versicolor        0.374307
# 23   sepal width      class  petal length   Iris-virginica        0.234348
# 24   petal width      class  petal length      Iris-setosa        0.189262
# 25   petal width      class  petal length  Iris-versicolor        0.331054
# 26   petal width      class  petal length   Iris-virginica        0.160297
# 27  sepal length      class   petal width      Iris-setosa        0.917614
# 28  sepal length      class   petal width  Iris-versicolor        1.426365
# 29  sepal length      class   petal width   Iris-virginica        0.650831
# 30   sepal width      class   petal width      Iris-setosa        0.995028
# 31   sepal width      class   petal width  Iris-versicolor        1.053648
# 32   sepal width      class   petal width   Iris-virginica        0.631405
# 33  petal length      class   petal width      Iris-setosa        0.495739
# 34  petal length      class   petal width  Iris-versicolor        1.869325
# 35  petal length      class   petal width   Iris-virginica        0.647259
#
#     subgroup_trend_strength trend_type  agg_trend  agg_trend_strength  \
# 0                  0.746780    lin_reg  -0.057268            0.109369
# 1                  0.525911    lin_reg  -0.057268            0.109369
# 2                  0.457228    lin_reg  -0.057268            0.109369
# 3                  0.263874    lin_reg   1.857510            0.871754
# 4                  0.754049    lin_reg   1.857510            0.871754
# 5                  0.864225    lin_reg   1.857510            0.871754
# 6                  0.279092    lin_reg   0.753841            0.817954
# 7                  0.546461    lin_reg   0.753841            0.817954
# 8                  0.281108    lin_reg   0.753841            0.817954
# 9                  0.746780    lin_reg  -0.208870            0.109369
# 10                 0.525911    lin_reg  -0.208870            0.109369
# 11                 0.457228    lin_reg  -0.208870            0.109369
# 12                 0.176695    lin_reg  -1.711201            0.420516
# 13                 0.560522    lin_reg  -1.711201            0.420516
# 14                 0.401045    lin_reg  -1.711201            0.420516
# 15                 0.279973    lin_reg  -0.627546            0.356544
# 16                 0.663999    lin_reg  -0.627546            0.356544
# 17                 0.537728    lin_reg  -0.627546            0.356544
# 18                 0.263874    lin_reg   0.409126            0.871754
# 19                 0.754049    lin_reg   0.409126            0.871754
# 20                 0.864225    lin_reg   0.409126            0.871754
# 21                 0.176695    lin_reg  -0.103339            0.420516
# 22                 0.560522    lin_reg  -0.103339            0.420516
# 23                 0.401045    lin_reg  -0.103339            0.420516
# 24                 0.306308    lin_reg   0.416419            0.962757
# 25                 0.786668    lin_reg   0.416419            0.962757
# 26                 0.322108    lin_reg   0.416419            0.962757
# 27                 0.279092    lin_reg   0.887519            0.817954
# 28                 0.546461    lin_reg   0.887519            0.817954
# 29                 0.281108    lin_reg   0.887519            0.817954
# 30                 0.279973    lin_reg  -0.202573            0.356544
# 31                 0.663999    lin_reg  -0.202573            0.356544
# 32                 0.537728    lin_reg  -0.202573            0.356544
# 33                 0.306308    lin_reg   2.225885            0.962757
# 34                 0.786668    lin_reg   2.225885            0.962757
# 35                 0.322108    lin_reg   2.225885            0.962757
#
#        comparison_type
# 0   aggregate-subgroup
# 1   aggregate-subgroup
# 2   aggregate-subgroup
# 3   aggregate-subgroup
# 4   aggregate-subgroup
# 5   aggregate-subgroup
# 6   aggregate-subgroup
# 7   aggregate-subgroup
# 8   aggregate-subgroup
# 9   aggregate-subgroup
# 10  aggregate-subgroup
# 11  aggregate-subgroup
# 12  aggregate-subgroup
# 13  aggregate-subgroup
# 14  aggregate-subgroup
# 15  aggregate-subgroup
# 16  aggregate-subgroup
# 17  aggregate-subgroup
# 18  aggregate-subgroup
# 19  aggregate-subgroup
# 20  aggregate-subgroup
# 21  aggregate-subgroup
# 22  aggregate-subgroup
# 23  aggregate-subgroup
# 24  aggregate-subgroup
# 25  aggregate-subgroup
# 26  aggregate-subgroup
# 27  aggregate-subgroup
# 28  aggregate-subgroup
# 29  aggregate-subgroup
# 30  aggregate-subgroup
# 31  aggregate-subgroup
# 32  aggregate-subgroup
# 33  aggregate-subgroup
# 34  aggregate-subgroup
# 35  aggregate-subgroup

# %%
linreg_obj2.regression_vars
# Out:
# [('sepal length', 'sepal width'),
#  ('sepal length', 'petal length'),
#  ('sepal length', 'petal width'),
#  ('sepal width', 'sepal length'),
#  ('sepal width', 'petal length'),
#  ('sepal width', 'petal width'),
#  ('petal length', 'sepal length'),
#  ('petal length', 'sepal width'),
#  ('petal length', 'petal width'),
#  ('petal width', 'sepal length'),
#  ('petal width', 'sepal width'),
#  ('petal width', 'petal length')]

# %%
linreg_obj2.var_weight_list
# Out:
# [(nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan)]

# %%
linreg_obj2.symmetric_vars
# Out:
# True

# %% [markdown]
# # Test object

# %%
indep, dep = zip(*corrobj.regression_vars)
corr_var_list = list(set(indep))
corr_var_list.extend(list(set(dep)))

corr_var_list = list(set(corr_var_list))
corr_var_list
# Out:
# ['petal length', 'sepal length', 'petal width', 'sepal width']

# %%
corr_mat = labeled_df.df[corr_var_list].corr()

# %%
corr_mat
# Out:
#               petal length  sepal length  petal width  sepal width
# petal length      1.000000      0.871754     0.962757    -0.420516
# sepal length      0.871754      1.000000     0.817954    -0.109369
# petal width       0.962757      0.817954     1.000000    -0.356544
# sepal width      -0.420516     -0.109369    -0.356544     1.000000

# %%
gby_df = labeled_df.df.groupby('class')
corr_mat_gby = gby_df.corr()
groupby_vars = list(gby_df.groups.keys())

sg_corr_target_vals = [(i,d, corr_mat_gby[i][g][d],g) for (i,d),g in
                                        itertools.product(corrobj.regression_vars,groupby_vars)]
sg_corr_target_vals
# Out:
# [('sepal length', 'sepal width', 0.7467803732639269, 'Iris-setosa'),
#  ('sepal length', 'sepal width', 0.5259107172828243, 'Iris-versicolor'),
#  ('sepal length', 'sepal width', 0.45722781639411286, 'Iris-virginica'),
#  ('petal length', 'sepal length', 0.26387409291868696, 'Iris-setosa'),
#  ('petal length', 'sepal length', 0.7540489585920161, 'Iris-versicolor'),
#  ('petal length', 'sepal length', 0.8642247329355762, 'Iris-virginica'),
#  ('petal length', 'sepal width', 0.17669462869680694, 'Iris-setosa'),
#  ('petal length', 'sepal width', 0.5605220916929818, 'Iris-versicolor'),
#  ('petal length', 'sepal width', 0.4010445773427851, 'Iris-virginica'),
#  ('petal width', 'sepal length', 0.27909157499959686, 'Iris-setosa'),
#  ('petal width', 'sepal length', 0.5464610715986299, 'Iris-versicolor'),
#  ('petal width', 'sepal length', 0.28110770915731953, 'Iris-virginica'),
#  ('petal width', 'sepal width', 0.27997288851690444, 'Iris-setosa'),
#  ('petal width', 'sepal width', 0.6639987200241115, 'Iris-versicolor'),
#  ('petal width', 'sepal width', 0.5377280262661888, 'Iris-virginica')]

# %%
[(i,d,g) for (i,d),g in
                                        itertools.product(corrobj.regression_vars,groupby_vars)]
# Out:
# [('sepal length', 'sepal width', 'Iris-setosa'),
#  ('sepal length', 'sepal width', 'Iris-versicolor'),
#  ('sepal length', 'sepal width', 'Iris-virginica'),
#  ('petal length', 'sepal length', 'Iris-setosa'),
#  ('petal length', 'sepal length', 'Iris-versicolor'),
#  ('petal length', 'sepal length', 'Iris-virginica'),
#  ('petal length', 'sepal width', 'Iris-setosa'),
#  ('petal length', 'sepal width', 'Iris-versicolor'),
#  ('petal length', 'sepal width', 'Iris-virginica'),
#  ('petal width', 'sepal length', 'Iris-setosa'),
#  ('petal width', 'sepal length', 'Iris-versicolor'),
#  ('petal width', 'sepal length', 'Iris-virginica'),
#  ('petal width', 'sepal width', 'Iris-setosa'),
#  ('petal width', 'sepal width', 'Iris-versicolor'),
#  ('petal width', 'sepal width', 'Iris-virginica')]

# %%
sg = corrobj.get_trends(gby_df,'subgroup_trend')
sg
# Out:
#      independent     dependent  subgroup_trend  subgroup_trend_strength  \
# 0   sepal length   sepal width        0.746780                 0.746780
# 1   sepal length   sepal width        0.525911                 0.525911
# 2   sepal length   sepal width        0.457228                 0.457228
# 3   petal length  sepal length        0.263874                 0.263874
# 4   petal length  sepal length        0.754049                 0.754049
# 5   petal length  sepal length        0.864225                 0.864225
# 6   petal length   sepal width        0.176695                 0.176695
# 7   petal length   sepal width        0.560522                 0.560522
# 8   petal length   sepal width        0.401045                 0.401045
# 9    petal width  sepal length        0.279092                 0.279092
# 10   petal width  sepal length        0.546461                 0.546461
# 11   petal width  sepal length        0.281108                 0.281108
# 12   petal width   sepal width        0.279973                 0.279973
# 13   petal width   sepal width        0.663999                 0.663999
# 14   petal width   sepal width        0.537728                 0.537728
#
#            subgroup group_feat    trend_type
# 0       Iris-setosa      class  pearson_corr
# 1   Iris-versicolor      class  pearson_corr
# 2    Iris-virginica      class  pearson_corr
# 3       Iris-setosa      class  pearson_corr
# 4   Iris-versicolor      class  pearson_corr
# 5    Iris-virginica      class  pearson_corr
# 6       Iris-setosa      class  pearson_corr
# 7   Iris-versicolor      class  pearson_corr
# 8    Iris-virginica      class  pearson_corr
# 9       Iris-setosa      class  pearson_corr
# 10  Iris-versicolor      class  pearson_corr
# 11   Iris-virginica      class  pearson_corr
# 12      Iris-setosa      class  pearson_corr
# 13  Iris-versicolor      class  pearson_corr
# 14   Iris-virginica      class  pearson_corr

# %%
df = corrobj.get_trends(labeled_df.df,'agg_trend')
df
# Out:
#     independent     dependent  agg_trend  agg_trend_strength    trend_type
# 0  sepal length   sepal width  -0.109369            0.109369  pearson_corr
# 1  petal length  sepal length   0.871754            0.871754  pearson_corr
# 2  petal length   sepal width  -0.420516            0.420516  pearson_corr
# 3   petal width  sepal length   0.817954            0.817954  pearson_corr
# 4   petal width   sepal width  -0.356544            0.356544  pearson_corr

# %%
pd.merge(sg,df)
# Out:
#      independent     dependent  subgroup_trend  subgroup_trend_strength  \
# 0   sepal length   sepal width        0.746780                 0.746780
# 1   sepal length   sepal width        0.525911                 0.525911
# 2   sepal length   sepal width        0.457228                 0.457228
# 3   petal length  sepal length        0.263874                 0.263874
# 4   petal length  sepal length        0.754049                 0.754049
# 5   petal length  sepal length        0.864225                 0.864225
# 6   petal length   sepal width        0.176695                 0.176695
# 7   petal length   sepal width        0.560522                 0.560522
# 8   petal length   sepal width        0.401045                 0.401045
# 9    petal width  sepal length        0.279092                 0.279092
# 10   petal width  sepal length        0.546461                 0.546461
# 11   petal width  sepal length        0.281108                 0.281108
# 12   petal width   sepal width        0.279973                 0.279973
# 13   petal width   sepal width        0.663999                 0.663999
# 14   petal width   sepal width        0.537728                 0.537728
#
#            subgroup group_feat    trend_type  agg_trend  agg_trend_strength
# 0       Iris-setosa      class  pearson_corr  -0.109369            0.109369
# 1   Iris-versicolor      class  pearson_corr  -0.109369            0.109369
# 2    Iris-virginica      class  pearson_corr  -0.109369            0.109369
# 3       Iris-setosa      class  pearson_corr   0.871754            0.871754
# 4   Iris-versicolor      class  pearson_corr   0.871754            0.871754
# 5    Iris-virginica      class  pearson_corr   0.871754            0.871754
# 6       Iris-setosa      class  pearson_corr  -0.420516            0.420516
# 7   Iris-versicolor      class  pearson_corr  -0.420516            0.420516
# 8    Iris-virginica      class  pearson_corr  -0.420516            0.420516
# 9       Iris-setosa      class  pearson_corr   0.817954            0.817954
# 10  Iris-versicolor      class  pearson_corr   0.817954            0.817954
# 11   Iris-virginica      class  pearson_corr   0.817954            0.817954
# 12      Iris-setosa      class  pearson_corr  -0.356544            0.356544
# 13  Iris-versicolor      class  pearson_corr  -0.356544            0.356544
# 14   Iris-virginica      class  pearson_corr  -0.356544            0.356544
